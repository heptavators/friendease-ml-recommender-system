# %%
import re
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
import tensorflow_recommenders as tfrs

from typing import Dict, Text
from datetime import datetime
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, StandardScaler

# %%
users_df = pd.read_csv('../data/users.csv')
users_df.head()
# Out:
#                                 user_id           user_name user_gender  \
# 0  ba01ce05-a24e-4fc6-8c53-21b1faa624a9   Manuella Beatrice           P
# 1  ebeac7d2-642f-42a6-9175-6eb86dbcf84d  Achmad Irvan Hakim           L
# 2  25fe48f2-a312-421d-8751-984b5e4a448f      Lubna Mawaddah           P
# 3  f5b01cb5-d06c-41fc-880a-694d9c74e96c     Fajar Ramadhan            L
# 4  b8307662-eb4f-4222-845e-771736274160  Gede Putra Nugraha           L
#
#   user_birth_date  user_age              user_location  \
# 0       5/27/2002        21             Banten, Serang
# 1      10/21/2003        20  Kalimantan Timur, Bontang
# 2       1/12/2003        20      Jawa Tengah, Semarang
# 3      10/27/2005        18    Jawa Barat, Tasikmalaya
# 4       6/19/2002        21        Jawa Barat, Cirebon
#
#                                            user_tags  \
# 0      Bernyanyi|Independen|Membaca|Disiplin|Menulis
# 1          Pecinta alam|Membaca|Kritis|Memasak|Ngopi
# 2  Puzzle|Bernyanyi|Penerjemah|Kecerdasan buatan|...
# 3  Olahraga|Analis keamanan|Memanjat|Binaraga|Han...
# 4              Dokter|Analitis|Kuliner|Musisi|Sosmed
#
#                                     user_preferences
# 0  Ingin memiliki teman yang bisa diajak kulinera...
# 1  Teman yang enak di ajak ngapa ngaapin (mabar,j...
# 2  Saya ingin teman yang bisa diajak kulineran, k...
# 3  Temen yang bisa diajak belajar, diskusi terkai...
# 4  Saya ingin teman yang bisa diajak berkembang b...

# %%
talents_df = pd.read_csv('../data/talents.csv')
talents_df.head()
# Out:
#                               talent_id               talent_name  \
# 0  fc0f6e4b-c397-40a4-a24c-d08b92aedc45   Pribadi Anwar Wicaksono
# 1  674c14d8-ed13-471a-aabf-ceef4e5bc44b           Perdana Anshari
# 2  f2427a83-eb72-47dd-aeaf-cf131b5cefa2    Dwi Nur Septasya Nahda
# 3  ac56a04d-aa98-4591-8e8c-2b188040c114     Asmara Tamara Liranda
# 4  d7a31753-7f7a-4d3a-80ec-bca26e578735  Adisyafitri Oky Septasya
#
#   talent_gender talent_birth_date  talent_age  \
# 0             L         24/4/1992          31
# 1             L         10/3/2005          18
# 2             P         10/3/2002          21
# 3             P         31/3/1992          31
# 4             P         12/7/1990          33
#
#                    talent_location  \
# 0                  Banten, Cilegon
# 1        Kalimantan Utara, Tarakan
# 2      Sumatera Selatan, Pagaralam
# 3  Sumatera Barat, Lima Puluh Kota
# 4      Kalimantan Timur, Samarinda
#
#                                          talent_tags  \
# 0  Badminton|Berjiwa petualang|Kpopers|Hiking|Ola...
# 1            Desain|Inovatif|Optimis|Seniman|Kreatif
# 2  Petualangan|Bersepeda|Kutu buku|Traveling|Kuliner
# 3      Analitis|Coding|Inovatif|Teknologi|Programmer
# 4          Ambisius|Membaca|Cerdas|Pengajar|Visioner
#
#                                   talent_description
# 0  Saya sangat menyukai Kpop, girlband favorit sa...
# 1  Saya adalah seorang seniman visual yang mencin...
# 2  Pecinta kuliner dan petualangan! Saya suka men...
# 3  Seorang pengembang perangkat lunak yang bersem...
# 4  Pengajar bahasa Inggris yang juga pencinta lit...

# %%
reviews_df = pd.read_csv('../data/reviews.csv')
reviews_df.head()
# Out:
#                                 user_id                             talent_id  \
# 0  5de6b455-0a80-4047-90e7-8ddee7ee2bb8  6742ab46-c8ca-4acc-99b2-9ba1c5bfccb6
# 1  5de6b455-0a80-4047-90e7-8ddee7ee2bb8  d9b90682-f5b4-45f7-b1ed-8b8044c945e1
# 2  bc92f639-6659-4732-ad42-cc62b377f811  1b18b89b-5434-422d-b2d9-294e4c64657e
# 3  9a8427dd-ef41-46d9-86fe-063129e8190e  931c2814-1f84-404f-851a-7fb075835d95
# 4  0e9ced1a-35a0-4ad5-a204-3d5c843de78f  ddc39acb-d29b-43f0-abcd-f54fe7be2904
#
#    rating                                             review
# 0       4  Talent ini sangat kreatif dalam fotografi, has...
# 1       3  Kemampuan olahraga talent ini memuaskan, tetap...
# 2       5  Sangat puas dengan pengalaman kuliner bersama ...
# 3       4  Talent ini memberikan konsultasi bisnis yang s...
# 4       2  Kemampuan gym dan jogging talent ini tidak ses...

# %% [markdown]
# ### Merging reviews with users and talents

# %%
ratings_df = pd.merge(pd.merge(reviews_df, talents_df, on='talent_id'), users_df, on='user_id')

# %%
ratings_df.head()
# Out:
#                                 user_id                             talent_id  \
# 0  5de6b455-0a80-4047-90e7-8ddee7ee2bb8  6742ab46-c8ca-4acc-99b2-9ba1c5bfccb6
# 1  5de6b455-0a80-4047-90e7-8ddee7ee2bb8  d9b90682-f5b4-45f7-b1ed-8b8044c945e1
# 2  600687d6-bf67-406d-a50e-768e3d2dd53d  6742ab46-c8ca-4acc-99b2-9ba1c5bfccb6
# 3  6a58a9cc-b016-4ff3-83d4-c41e735bf4df  6742ab46-c8ca-4acc-99b2-9ba1c5bfccb6
# 4  6a58a9cc-b016-4ff3-83d4-c41e735bf4df  167c23a2-5f3d-48f1-87a5-e7e8b4ce8e44
#
#    rating                                             review  \
# 0       4  Talent ini sangat kreatif dalam fotografi, has...
# 1       3  Kemampuan olahraga talent ini memuaskan, tetap...
# 2       3  Fotografer talent ini memiliki kemampuan yang ...
# 3       5  Talent ini memiliki keterampilan mendengarkan ...
# 4       3  Secara umum ok. Kemampuan bersepeda dan berkeb...
#
#                      talent_name talent_gender talent_birth_date  talent_age  \
# 0                Muhammad Hamzah             L        21/12/1991          32
# 1            Tedi Febrianto Arya             L         7/10/1979          44
# 2                Muhammad Hamzah             L        21/12/1991          32
# 3                Muhammad Hamzah             L        21/12/1991          32
# 4  Sayid Bryan Karim Restiantoro             L         26/8/1978          45
#
#                    talent_location  \
# 0       Sulawesi Utara, Kotamobagu
# 1  Sumatera Utara, Pematangsiantar
# 2       Sulawesi Utara, Kotamobagu
# 3       Sulawesi Utara, Kotamobagu
# 4            Jawa Timur, Mojokerto
#
#                                   talent_tags  \
# 0  Ambisius|Editor|Kreatif|Fotografer|Kuliner
# 1    Badminton|Cerdas|Pengajar|Ramah|Olahraga
# 2  Ambisius|Editor|Kreatif|Fotografer|Kuliner
# 3  Ambisius|Editor|Kreatif|Fotografer|Kuliner
# 4      Penyanyi|Musisi|Kreatif|Psikolog|Ramah
#
#                                   talent_description                user_name  \
# 0  Fotografer yang mengkhususkan diri dalam fotog...                    Irgi
# 1  Seorang mantan pemain bulu tangkis yang berali...                    Irgi
# 2  Fotografer yang mengkhususkan diri dalam fotog...  Irhamulloh Angga Taufik
# 3  Fotografer yang mengkhususkan diri dalam fotog...           Kevin Setiawan
# 4  Pecinta musik yang memiliki kecintaan pada ber...           Kevin Setiawan
#
#   user_gender user_birth_date  user_age           user_location  \
# 0           L        7/3/2002        21    Jawa Timur, Pasuruan
# 1           L        7/3/2002        21    Jawa Timur, Pasuruan
# 2           L       18/2/1997        26         Banten, Cilegon
# 3           L       9/13/2000        23  Sumatera Utara, Binjai
# 4           L       9/13/2000        23  Sumatera Utara, Binjai
#
#                                            user_tags  \
# 0  Astrografi|Menggambar|Ambisius|Ahli nutrisi|Tr...
# 1  Astrografi|Menggambar|Ambisius|Ahli nutrisi|Tr...
# 2               Cerdas|Seni|Berkebun|Grafity|Pelukis
# 3   Konsultan|Dokter|Sepak bola|Pet lovers|Memancing
# 4   Konsultan|Dokter|Sepak bola|Pet lovers|Memancing
#
#                                     user_preferences
# 0  Yang bisa diajak tukeran gambar, ngobrolin hal...
# 1  Yang bisa diajak tukeran gambar, ngobrolin hal...
# 2  Seorang pelukis yang suka seni, grafity, berke...
# 3  Biasa diajak seneng bareng, maen game bareng, ...
# 4  Biasa diajak seneng bareng, maen game bareng, ...

# %%
ratings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1026 entries, 0 to 1025
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   user_id             1026 non-null   object
#  1   talent_id           1026 non-null   object
#  2   rating              1026 non-null   int64
#  3   review              1026 non-null   object
#  4   talent_name         1026 non-null   object
#  5   talent_gender       1026 non-null   object
#  6   talent_birth_date   1026 non-null   object
#  7   talent_age          1026 non-null   int64
#  8   talent_location     1026 non-null   object
#  9   talent_tags         1026 non-null   object
#  10  talent_description  1026 non-null   object
#  11  user_name           1026 non-null   object
#  12  user_gender         1026 non-null   object
#  13  user_birth_date     1026 non-null   object
#  14  user_age            1026 non-null   int64
#  15  user_location       1026 non-null   object
#  16  user_tags           1026 non-null   object
#  17  user_preferences    1026 non-null   object
# dtypes: int64(3), object(15)
# memory usage: 152.3+ KB

# %% [markdown]
# ### Preprocessing data

# %%
genders_encoder = LabelEncoder()
genders = ratings_df["user_gender"].unique()

# %%
genders_encoder.fit(genders)
# Out:
# LabelEncoder()

# %%
ratings_df.loc[:, "user_gender"] = genders_encoder.transform(ratings_df["user_gender"])
ratings_df.loc[:, "talent_gender"] = genders_encoder.transform(ratings_df["talent_gender"])

# %%
ratings_df.head()
# Out:
#                                 user_id                             talent_id  \
# 0  5de6b455-0a80-4047-90e7-8ddee7ee2bb8  6742ab46-c8ca-4acc-99b2-9ba1c5bfccb6
# 1  5de6b455-0a80-4047-90e7-8ddee7ee2bb8  d9b90682-f5b4-45f7-b1ed-8b8044c945e1
# 2  600687d6-bf67-406d-a50e-768e3d2dd53d  6742ab46-c8ca-4acc-99b2-9ba1c5bfccb6
# 3  6a58a9cc-b016-4ff3-83d4-c41e735bf4df  6742ab46-c8ca-4acc-99b2-9ba1c5bfccb6
# 4  6a58a9cc-b016-4ff3-83d4-c41e735bf4df  167c23a2-5f3d-48f1-87a5-e7e8b4ce8e44
#
#    rating                                             review  \
# 0       4  Talent ini sangat kreatif dalam fotografi, has...
# 1       3  Kemampuan olahraga talent ini memuaskan, tetap...
# 2       3  Fotografer talent ini memiliki kemampuan yang ...
# 3       5  Talent ini memiliki keterampilan mendengarkan ...
# 4       3  Secara umum ok. Kemampuan bersepeda dan berkeb...
#
#                      talent_name  talent_gender talent_birth_date  talent_age  \
# 0                Muhammad Hamzah              0        21/12/1991          32
# 1            Tedi Febrianto Arya              0         7/10/1979          44
# 2                Muhammad Hamzah              0        21/12/1991          32
# 3                Muhammad Hamzah              0        21/12/1991          32
# 4  Sayid Bryan Karim Restiantoro              0         26/8/1978          45
#
#                    talent_location  \
# 0       Sulawesi Utara, Kotamobagu
# 1  Sumatera Utara, Pematangsiantar
# 2       Sulawesi Utara, Kotamobagu
# 3       Sulawesi Utara, Kotamobagu
# 4            Jawa Timur, Mojokerto
#
#                                   talent_tags  \
# 0  Ambisius|Editor|Kreatif|Fotografer|Kuliner
# 1    Badminton|Cerdas|Pengajar|Ramah|Olahraga
# 2  Ambisius|Editor|Kreatif|Fotografer|Kuliner
# 3  Ambisius|Editor|Kreatif|Fotografer|Kuliner
# 4      Penyanyi|Musisi|Kreatif|Psikolog|Ramah
#
#                                   talent_description                user_name  \
# 0  Fotografer yang mengkhususkan diri dalam fotog...                    Irgi
# 1  Seorang mantan pemain bulu tangkis yang berali...                    Irgi
# 2  Fotografer yang mengkhususkan diri dalam fotog...  Irhamulloh Angga Taufik
# 3  Fotografer yang mengkhususkan diri dalam fotog...           Kevin Setiawan
# 4  Pecinta musik yang memiliki kecintaan pada ber...           Kevin Setiawan
#
#    user_gender user_birth_date  user_age           user_location  \
# 0            0        7/3/2002        21    Jawa Timur, Pasuruan
# 1            0        7/3/2002        21    Jawa Timur, Pasuruan
# 2            0       18/2/1997        26         Banten, Cilegon
# 3            0       9/13/2000        23  Sumatera Utara, Binjai
# 4            0       9/13/2000        23  Sumatera Utara, Binjai
#
#                                            user_tags  \
# 0  Astrografi|Menggambar|Ambisius|Ahli nutrisi|Tr...
# 1  Astrografi|Menggambar|Ambisius|Ahli nutrisi|Tr...
# 2               Cerdas|Seni|Berkebun|Grafity|Pelukis
# 3   Konsultan|Dokter|Sepak bola|Pet lovers|Memancing
# 4   Konsultan|Dokter|Sepak bola|Pet lovers|Memancing
#
#                                     user_preferences
# 0  Yang bisa diajak tukeran gambar, ngobrolin hal...
# 1  Yang bisa diajak tukeran gambar, ngobrolin hal...
# 2  Seorang pelukis yang suka seni, grafity, berke...
# 3  Biasa diajak seneng bareng, maen game bareng, ...
# 4  Biasa diajak seneng bareng, maen game bareng, ...

# %%
numerical_columns = ["rating" , "user_gender", "talent_gender", "user_age", "talent_age"]

for column in ratings_df.columns:
    if column in numerical_columns:
        ratings_df[column] = ratings_df[column].astype(np.int32)
    else:
        ratings_df[column] = ratings_df[column].astype(np.str_)

# %%
ratings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1026 entries, 0 to 1025
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   user_id             1026 non-null   object
#  1   talent_id           1026 non-null   object
#  2   rating              1026 non-null   int32
#  3   review              1026 non-null   object
#  4   talent_name         1026 non-null   object
#  5   talent_gender       1026 non-null   int32
#  6   talent_birth_date   1026 non-null   object
#  7   talent_age          1026 non-null   int32
#  8   talent_location     1026 non-null   object
#  9   talent_tags         1026 non-null   object
#  10  talent_description  1026 non-null   object
#  11  user_name           1026 non-null   object
#  12  user_gender         1026 non-null   int32
#  13  user_birth_date     1026 non-null   object
#  14  user_age            1026 non-null   int32
#  15  user_location       1026 non-null   object
#  16  user_tags           1026 non-null   object
#  17  user_preferences    1026 non-null   object
# dtypes: int32(5), object(13)
# memory usage: 132.3+ KB

# %% [markdown]
# ### Building data pipeline

# %%
ratings = tf.data.Dataset.from_tensor_slices(
    dict(
        ratings_df[[
                'user_id', 'talent_id', 'rating', 'review', 'talent_gender', 'talent_age', 'talent_location', 'talent_tags', 'talent_description', 'user_gender', 'user_age', 'user_location', 'user_tags', 'user_preferences'
            ]]
        )
)
talents = tf.data.Dataset.from_tensor_slices(
    dict(
        talents_df[[
                'talent_id', 
                # 'talent_gender', 'talent_age', 'talent_location', 'talent_tags', 'talent_description'
            ]]
        )
)

# %%
ratings = ratings.map(
    lambda x: {
        "user_id": tf.cast(x["user_id"], tf.string),
        "talent_id": tf.cast(x["talent_id"], tf.string),
        "rating": tf.cast(x["rating"], tf.int32),
        "review": tf.cast(x["review"], tf.string),
        "talent_gender": tf.cast(x["talent_gender"], tf.int32),
        "talent_age": tf.cast(x["talent_age"], tf.int32),
        "talent_location": tf.cast(x["talent_location"], tf.string),
        "talent_tags": tf.cast(x["talent_tags"], tf.string),
        "talent_description": tf.cast(x["talent_description"], tf.string),
        "user_gender": tf.cast(x["user_gender"], tf.int32),
        "user_age": tf.cast(x["user_age"], tf.int32),
        "user_location": tf.cast(x["user_location"], tf.string),
        "user_tags": tf.cast(x["user_tags"], tf.string),
        "user_preferences": tf.cast(x["user_preferences"], tf.string),
    }
)

talents = talents.map(
    lambda x: {
        "talent_id": tf.cast(x["talent_id"], tf.string),
        # "talent_gender": tf.cast(x["talent_gender"], tf.int32),
        # "talent_age": tf.cast(x["talent_age"], tf.int32),
        # "talent_location": tf.cast(x["talent_location"], tf.string),
        # "talent_tags": tf.cast(x["talent_tags"], tf.string),
        # "talent_description": tf.cast(x["talent_description"], tf.string),
    }
)

# %%
feature_names = [
    "user_id",
    "talent_id",
    "rating",
    "review",
    "talent_gender",
    "talent_age",
    "talent_location",
    "talent_tags",
    "talent_description",
    "user_gender",
    "user_age",
    "user_location",
    "user_tags",
    "user_preferences",
]

vocabularies = {}

for feature_name in feature_names:
    vocab = ratings.batch(1_000).map(lambda x : x[feature_name])
    vocabularies[feature_name] = np.unique(np.concatenate(list(vocab)))

# %%
train_size = int(0.8 * len(ratings_df))
test_size = len(ratings_df) - train_size

assert train_size + test_size == len(ratings_df)

train_size, test_size
# Out:
# (820, 206)

# %%
tf.random.set_seed(42)
shuffled = ratings.shuffle(len(ratings_df), seed=42, reshuffle_each_iteration=False)

train = shuffled.take(train_size)
test = shuffled.skip(train_size).take(test_size)

cached_train = train.shuffle(len(ratings_df)).batch(1024).cache()
cached_test = test.batch(512).cache()

# %% [markdown]
# ### Bulding model architecture

# %%
class UserModel(tf.keras.Model):

    def __init__(self):
        super().__init__()
        self.embedding_dimension = 32

        str_features = ["user_id", "user_location", "user_tags"]
        int_features = ["user_gender", "user_age", "rating"]
        text_features = ["user_preferences", "review", "user_tags", "user_location"]

        self._all_features = str_features + int_features + text_features
        self._embeddings = {}

        # Compute embeddings for string features.
        for feature_name in str_features:
            vocabulary = vocabularies[feature_name]
            self._embeddings[feature_name] = tf.keras.Sequential(
                [
                    tf.keras.layers.StringLookup(
                        vocabulary=vocabulary, mask_token=None
                    ),
                    tf.keras.layers.Embedding(
                        len(vocabulary) + 1, self.embedding_dimension
                    ),
                ]
            )

        # Compute embeddings for int features.
        for feature_name in int_features:
            vocabulary = vocabularies[feature_name]
            self._embeddings[feature_name] = tf.keras.Sequential(
                [
                    tf.keras.layers.IntegerLookup(
                        vocabulary=vocabulary, mask_token=None
                    ),
                    tf.keras.layers.Embedding(
                        len(vocabulary) + 1, self.embedding_dimension
                    ),
                ]
            )

        # Compute embeddings for text features.
        for feature_name in text_features:
            vocabulary = vocabularies[feature_name]
            vectorization_layer = tf.keras.layers.TextVectorization()
            vectorization_layer.adapt(cached_train.map(lambda x: x[feature_name]))
            self._embeddings[feature_name] = tf.keras.Sequential(
                [
                    vectorization_layer,
                    tf.keras.layers.Embedding(
                        len(vectorization_layer.get_vocabulary()),
                        self.embedding_dimension,
                        mask_zero=True,
                    ),
                    tf.keras.layers.GlobalAveragePooling1D(),
                ]
            )

    def call(self, inputs: Dict[Text, tf.Tensor]) -> tf.Tensor:
        # Concatenate embeddings
        embeddings = []
        for feature_name in self._all_features:
            embedding_fn = self._embeddings[feature_name]
            embeddings.append(embedding_fn(inputs[feature_name]))

        return tf.concat(embeddings, axis=1)

# %%
class QueryModel(tf.keras.Model):
    """Model for encoding user queries."""

    def __init__(self, layer_sizes):
        """Model for encoding user queries.

        Args:
          layer_sizes:
            A list of integers where the i-th entry represents the number of units
            the i-th layer contains.
        """
        super().__init__()
        
        # We first use the user model for generating embeddings.
        self.embedding_model = UserModel()

        # Then construct the layers.
        self.dense_layers = tf.keras.Sequential()

        # Use the ReLU activation for all but the last layer.
        for layer_size in layer_sizes[:-1]:
            self.dense_layers.add(tf.keras.layers.Dense(layer_size, activation="relu"))

        # No activation for the last layer.
        for layer_size in layer_sizes[-1:]:
            self.dense_layers.add(tf.keras.layers.Dense(layer_size))


    def call(self, inputs: Dict[Text, tf.Tensor]) -> tf.Tensor:
        feature_embedding = self.embedding_model(inputs)
        return self.dense_layers(feature_embedding)

# %%
class TalentModel(tf.keras.Model):
    def __init__(self):
        super().__init__()
        self.embedding_dimension = 32

        str_features = ["talent_id"]
        int_features = []
        text_features = ["talent_id"]

        self._all_features = str_features + int_features + text_features
        self._embeddings = {}

        # Compute embeddings for string features.
        for feature_name in str_features:
            vocabulary = vocabularies[feature_name]
            self._embeddings[feature_name] = tf.keras.Sequential(
                [
                    tf.keras.layers.StringLookup(
                        vocabulary=vocabulary, mask_token=None
                    ),
                    tf.keras.layers.Embedding(
                        len(vocabulary) + 1, self.embedding_dimension
                    ),
                ]
            )

        # Compute embeddings for int features.
        for feature_name in int_features:
            vocabulary = vocabularies[feature_name]
            self._embeddings[feature_name] = tf.keras.Sequential(
                [
                    tf.keras.layers.IntegerLookup(
                        vocabulary=vocabulary, mask_token=None
                    ),
                    tf.keras.layers.Embedding(
                        len(vocabulary) + 1, self.embedding_dimension
                    ),
                ]
            )

        # Compute embeddings for text features.
        for feature_name in text_features:
            vocabulary = vocabularies[feature_name]
            vectorization_layer = tf.keras.layers.TextVectorization()
            vectorization_layer.adapt(cached_train.map(lambda x: x[feature_name]))
            self._embeddings[feature_name] = tf.keras.Sequential(
                [
                    vectorization_layer,
                    tf.keras.layers.Embedding(
                        len(vectorization_layer.get_vocabulary()),
                        self.embedding_dimension,
                        mask_zero=True,
                    ),
                    tf.keras.layers.GlobalAveragePooling1D(),
                ]
            )

    def call(self, inputs: Dict[Text, tf.Tensor]) -> tf.Tensor:
        # Concatenate embeddings
        embeddings = []
        for feature_name in self._all_features:
            embedding_fn = self._embeddings[feature_name]
            embeddings.append(embedding_fn(inputs[feature_name]))

        return tf.concat(embeddings, axis=1)

# %%
class CandidateModel(tf.keras.Model):
    """Model for encoding talents."""

    def __init__(self, layer_sizes):
        """Model for encoding talents.

        Args:
          layer_sizes:
            A list of integers where the i-th entry represents the number of units
            the i-th layer contains.
        """
        super().__init__()
        self.embedding_model = TalentModel()

        # Then construct the layers.
        self.dense_layers = tf.keras.Sequential()

        # Use the ReLU activation for all but the last layer.
        for layer_size in layer_sizes[:-1]:
            self.dense_layers.add(tf.keras.layers.Dense(layer_size, activation="relu"))

        # No activation for the last layer.
        for layer_size in layer_sizes[-1:]:
            self.dense_layers.add(tf.keras.layers.Dense(layer_size))


    def call(self, inputs: Dict[Text, tf.Tensor]) -> tf.Tensor:
        feature_embedding = self.embedding_model(inputs)
        return self.dense_layers(feature_embedding)

# %%
class FriendEaseModel(tfrs.models.Model):
    def __init__(self, layer_sizes, rating_weight: float, retrieval_weight: float):
        super().__init__()

        # User and talent models.
        self.query_model = QueryModel(layer_sizes)
        self.candidate_model = CandidateModel(layer_sizes)

        # A small model to take in user and movie embeddings and predict ratings.
        # We can make this as complicated as we want as long as we output a scalar
        # as our prediction.
        self.rating_model = tf.keras.Sequential(
            [
                tf.keras.layers.Dense(256, activation="relu"),
                tf.keras.layers.Dense(128, activation="relu"),
                tf.keras.layers.Dense(1),
            ]
        )

        # The tasks.
        self.rating_task: tf.keras.layers.Layer = tfrs.tasks.Ranking(
            loss=tf.keras.losses.MeanSquaredError(),
            metrics=[tf.keras.metrics.RootMeanSquaredError()],
        )
        self.retrieval_task = tfrs.tasks.Retrieval(
            metrics=tfrs.metrics.FactorizedTopK(
                candidates=talents.batch(128).map(self.candidate_model),
            ),
        )

        # The loss weights.
        self.rating_weight = rating_weight
        self.retrieval_weight = retrieval_weight

    def call(self, features: Dict[Text, tf.Tensor]) -> tf.Tensor:
        # We pick out the user features and pass them into the user model.
        user_embeddings = self.query_model(
            {
                "user_id": features["user_id"], 
                "user_gender": features["user_gender"], 
                "user_age": features["user_age"], 
                "user_location": features["user_location"], 
                "user_tags": features["user_tags"], 
                "user_preferences": features["user_preferences"],
                "rating": features["rating"],
                "review": features["review"],
            }
        )
        # And pick out the movie features and pass them into the movie model.
        talent_embeddings = self.candidate_model({"talent_id": features["talent_id"]})

        return (
            user_embeddings,
            talent_embeddings,
            # We apply the multi-layered rating model to a concatentation of
            # user and movie embeddings.
            self.rating_model(tf.concat([user_embeddings, talent_embeddings], axis=1)),
        )

    def compute_loss(
        self, features: Dict[Text, tf.Tensor], training=False
    ) -> tf.Tensor:
        rate = features["rating"]

        user_embeddings, talent_embeddings, rating_predictions = self(features)

        # We compute the loss for each task.

        rating_loss = self.rating_task(
            labels=rate,
            predictions=rating_predictions,
        )
        retrieval_loss = self.retrieval_task(user_embeddings, talent_embeddings)

        # And combine them using the loss weights.
        return self.rating_weight * rating_loss + self.retrieval_weight * retrieval_loss

# %%
num_epochs = 100

model = FriendEaseModel([64], rating_weight=1.0, retrieval_weight=1.0)
model.compile(optimizer=tf.keras.optimizers.Adagrad(1e-1))

one_layer_history = model.fit(
    cached_train,
    validation_data=cached_test,
    epochs=num_epochs,
)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 3s 3s/step - root_mean_squared_error: 4.1235 - factorized_top_k/top_1_categorical_accuracy: 0.0146 - factorized_top_k/top_5_categorical_accuracy: 0.0500 - factorized_top_k/top_10_categorical_accuracy: 0.0768 - factorized_top_k/top_50_categorical_accuracy: 0.1805 - factorized_top_k/top_100_categorical_accuracy: 0.2537 - loss: 5518.6143 - regularization_loss: 0.0000e+00 - total_loss: 5518.6143 - val_root_mean_squared_error: 2.5174 - val_factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_5_categorical_accuracy: 0.0146 - val_factorized_top_k/top_10_categorical_accuracy: 0.0243 - val_factorized_top_k/top_50_categorical_accuracy: 0.1019 - val_factorized_top_k/top_100_categorical_accuracy: 0.1796 - val_loss: 1103.3612 - val_regularization_loss: 0.0000e+00 - val_total_loss: 1103.3612
# Epoch 2/100
# 1/1 [==============================] - 0s 159ms/step - root_mean_squared_error: 2.5731 - factorized_top_k/top_1_categorical_accuracy: 0.0024 - factorized_top_k/top_5_categorical_accuracy: 0.0098 - factorized_top_k/top_10_categorical_accuracy: 0.0244 - factorized_top_k/top_50_categorical_accuracy: 0.1220 - factorized_top_k/top_100_categorical_accuracy: 0.2817 - loss: 5484.7729 - regularization_loss: 0.0000e+00 - total_loss: 5484.7729 - val_root_mean_squared_error: 12.8701 - val_factorized_top_k/top_1_categorical_accuracy: 0.0049 - val_factorized_top_k/top_5_categorical_accuracy: 0.0194 - val_factorized_top_k/top_10_categorical_accuracy: 0.0340 - val_factorized_top_k/top_50_categorical_accuracy: 0.1602 - val_factorized_top_k/top_100_categorical_accuracy: 0.2718 - val_loss: 1267.7549 - val_regularization_loss: 0.0000e+00 - val_total_loss: 1267.7549
# Epoch 3/100
# 1/1 [==============================] - 0s 165ms/step - root_mean_squared_error: 13.1688 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_100_categorical_accuracy: 0.0049 - loss: 5308.0518 - regularization_loss: 0.0000e+00 - total_loss: 5308.0518 - val_root_mean_squared_error: 12.3631 - val_factorized_top_k/top_1_categorical_accuracy: 0.0049 - val_factorized_top_k/top_5_categorical_accuracy: 0.0243 - val_factorized_top_k/top_10_categorical_accuracy: 0.0291 - val_factorized_top_k/top_50_categorical_accuracy: 0.1408 - val_factorized_top_k/top_100_categorical_accuracy: 0.2039 - val_loss: 3331.6995 - val_regularization_loss: 0.0000e+00 - val_total_loss: 3331.6995
# Epoch 4/100
# 1/1 [==============================] - 0s 164ms/step - root_mean_squared_error: 12.8651 - factorized_top_k/top_1_categorical_accuracy: 0.1549 - factorized_top_k/top_5_categorical_accuracy: 0.2183 - factorized_top_k/top_10_categorical_accuracy: 0.2659 - factorized_top_k/top_50_categorical_accuracy: 0.4963 - factorized_top_k/top_100_categorical_accuracy: 0.6293 - loss: 9212.7383 - regularization_loss: 0.0000e+00 - total_loss: 9212.7383 - val_root_mean_squared_error: 3.4799 - val_factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_5_categorical_accuracy: 0.0194 - val_factorized_top_k/top_10_categorical_accuracy: 0.0291 - val_factorized_top_k/top_50_categorical_accuracy: 0.0971 - val_factorized_top_k/top_100_categorical_accuracy: 0.1796 - val_loss: 3172.4270 - val_regularization_loss: 0.0000e+00 - val_total_loss: 3172.4270
# Epoch 5/100
# 1/1 [==============================] - 0s 166ms/step - root_mean_squared_error: 3.4890 - factorized_top_k/top_1_categorical_accuracy: 0.0561 - factorized_top_k/top_5_categorical_accuracy: 0.0963 - factorized_top_k/top_10_categorical_accuracy: 0.1329 - factorized_top_k/top_50_categorical_accuracy: 0.2622 - factorized_top_k/top_100_categorical_accuracy: 0.4146 - loss: 11950.8535 - regularization_loss: 0.0000e+00 - total_loss: 11950.8535 - val_root_mean_squared_error: 2.6109 - val_factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_5_categorical_accuracy: 0.0049 - val_factorized_top_k/top_10_categorical_accuracy: 0.0146 - val_factorized_top_k/top_50_categorical_accuracy: 0.0922 - val_factorized_top_k/top_100_categorical_accuracy: 0.2039 - val_loss: 2494.3445 - val_regularization_loss: 0.0000e+00 - val_total_loss: 2494.3445
# Epoch 6/100
# 1/1 [==============================] - 0s 179ms/step - root_mean_squared_error: 2.3425 - factorized_top_k/top_1_categorical_accuracy: 0.0037 - factorized_top_k/top_5_categorical_accuracy: 0.0122 - factorized_top_k/top_10_categorical_accuracy: 0.0220 - factorized_top_k/top_50_categorical_accuracy: 0.1793 - factorized_top_k/top_100_categorical_accuracy: 0.4110 - loss: 8942.0186 - regularization_loss: 0.0000e+00 - total_loss: 8942.0186 - val_root_mean_squared_error: 24.3473 - val_factorized_top_k/top_1_categorical_accuracy: 0.0049 - val_factorized_top_k/top_5_categorical_accuracy: 0.0097 - val_factorized_top_k/top_10_categorical_accuracy: 0.0146 - val_factorized_top_k/top_50_categorical_accuracy: 0.0728 - val_factorized_top_k/top_100_categorical_accuracy: 0.1748 - val_loss: 5966.6274 - val_regularization_loss: 0.0000e+00 - val_total_loss: 5966.6274
# Epoch 7/100
# 1/1 [==============================] - 0s 212ms/step - root_mean_squared_error: 28.0175 - factorized_top_k/top_1_categorical_accuracy: 0.1012 - factorized_top_k/top_5_categorical_accuracy: 0.1512 - factorized_top_k/top_10_categorical_accuracy: 0.1732 - factorized_top_k/top_50_categorical_accuracy: 0.3171 - factorized_top_k/top_100_categorical_accuracy: 0.3988 - loss: 22283.0254 - regularization_loss: 0.0000e+00 - total_loss: 22283.0254 - val_root_mean_squared_error: 7.4391 - val_factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_5_categorical_accuracy: 0.0097 - val_factorized_top_k/top_10_categorical_accuracy: 0.0340 - val_factorized_top_k/top_50_categorical_accuracy: 0.0971 - val_factorized_top_k/top_100_categorical_accuracy: 0.2039 - val_loss: 3523.6863 - val_regularization_loss: 0.0000e+00 - val_total_loss: 3523.6863
# Epoch 8/100
# 1/1 [==============================] - 0s 166ms/step - root_mean_squared_error: 8.7597 - factorized_top_k/top_1_categorical_accuracy: 0.0341 - factorized_top_k/top_5_categorical_accuracy: 0.0878 - factorized_top_k/top_10_categorical_accuracy: 0.1293 - factorized_top_k/top_50_categorical_accuracy: 0.3732 - factorized_top_k/top_100_categorical_accuracy: 0.5744 - loss: 9826.3213 - regularization_loss: 0.0000e+00 - total_loss: 9826.3213 - val_root_mean_squared_error: 8.9359 - val_factorized_top_k/top_1_categorical_accuracy: 0.0049 - val_factorized_top_k/top_5_categorical_accuracy: 0.0146 - val_factorized_top_k/top_10_categorical_accuracy: 0.0291 - val_factorized_top_k/top_50_categorical_accuracy: 0.0971 - val_factorized_top_k/top_100_categorical_accuracy: 0.1893 - val_loss: 4657.9639 - val_regularization_loss: 0.0000e+00 - val_total_loss: 4657.9639
# Epoch 9/100
# 1/1 [==============================] - 0s 163ms/step - root_mean_squared_error: 9.4923 - factorized_top_k/top_1_categorical_accuracy: 0.2049 - factorized_top_k/top_5_categorical_accuracy: 0.3183 - factorized_top_k/top_10_categorical_accuracy: 0.3878 - factorized_top_k/top_50_categorical_accuracy: 0.6061 - factorized_top_k/top_100_categorical_accuracy: 0.7439 - loss: 11373.5420 - regularization_loss: 0.0000e+00 - total_loss: 11373.5420 - val_root_mean_squared_error: 3.9773 - val_factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - val_factorized_top_k/top_5_categorical_accuracy: 0.0243 - val_factorized_top_k/top_10_categorical_accuracy: 0.0388 - val_factorized_top_k/top_50_categorical_accuracy: 0.1068 - val_factorized_top_k/top_100_categorical_accuracy: 0.2136 - val_loss: 4787.7998 - val_regularization_loss: 0.0000e+00 - val_total_loss: 4787.7998
# Epoch 10/100
# 1/1 [==============================] - 0s 167ms/step - root_mean_squared_error: 4.0485 - factorized_top_k/top_1_categorical_accuracy: 0.3329 - factorized_top_k/top_5_categorical_accuracy: 0.4183 - factorized_top_k/top_10_categorical_accuracy: 0.4732 - factorized_top_k/top_50_categorical_accuracy: 0.6768 - factorized_top_k/top_100_categorical_accuracy: 0.7720 - loss: 13342.6836 - regularization_loss: 0.0000e+00 - total_loss: 13342.6836 - val_root_mean_squared_error: 3.7768 - val_factorized_top_k/top_1_categorical_accuracy: 0.0049 - val_factorized_top_k/top_5_categorical_accuracy: 0.0388 - val_factorized_top_k/top_10_categorical_accuracy: 0.0534 - val_factorized_top_k/top_50_categorical_accuracy: 0.1262 - val_factorized_top_k/top_100_categorical_accuracy: 0.1845 - val_loss: 3987.5239 - val_regularization_loss: 0.0000e+00 - val_total_loss: 3987.5239
# Epoch 11/100
# 1/1 [==============================] - 0s 169ms/step - root_mean_squared_error: 3.8826 - factorized_top_k/top_1_categorical_accuracy: 0.2073 - factorized_top_k/top_5_categorical_accuracy: 0.4305 - factorized_top_k/top_10_categorical_accuracy: 0.5110 - factorized_top_k/top_50_categorical_accuracy: 0.7634 - factorized_top_k/top_100_categorical_accuracy: 0.8561 - loss: 8607.5537 - regularization_loss: 0.0000e+00 - total_loss: 8607.5537 - val_root_mean_squared_error: 3.2899 - val_factorized_top_k/top_1_categorical_accuracy: 0.0097 - val_factorized_top_k/top_5_categorical_accuracy: 0.0291 - val_factorized_top_k/top_10_categorical_accuracy: 0.0485 - val_factorized_top_k/top_50_categorical_accuracy: 0.1505 - val_factorized_top_k/top_100_categorical_accuracy: 0.2476 - val_loss: 3467.0093 - val_regularization_loss: 0.0000e+00 - val_total_loss: 3467.0093
# Epoch 12/100
# 1/1 [==============================] - 0s 167ms/step - root_mean_squared_error: 3.3669 - factorized_top_k/top_1_categorical_accuracy: 0.3244 - factorized_top_k/top_5_categorical_accuracy: 0.6488 - factorized_top_k/top_10_categorical_accuracy: 0.7646 - factorized_top_k/top_50_categorical_accuracy: 0.9244 - factorized_top_k/top_100_categorical_accuracy: 0.9634 - loss: 4332.6382 - regularization_loss: 0.0000e+00 - total_loss: 4332.6382 - val_root_mean_squared_error: 2.4210 - val_factorized_top_k/top_1_categorical_accuracy: 0.0291 - val_factorized_top_k/top_5_categorical_accuracy: 0.0437 - val_factorized_top_k/top_10_categorical_accuracy: 0.0631 - val_factorized_top_k/top_50_categorical_accuracy: 0.1359 - val_factorized_top_k/top_100_categorical_accuracy: 0.2233 - val_loss: 2700.9932 - val_regularization_loss: 0.0000e+00 - val_total_loss: 2700.9932
# Epoch 13/100
# 1/1 [==============================] - 0s 163ms/step - root_mean_squared_error: 2.4103 - factorized_top_k/top_1_categorical_accuracy: 0.4354 - factorized_top_k/top_5_categorical_accuracy: 0.8293 - factorized_top_k/top_10_categorical_accuracy: 0.8829 - factorized_top_k/top_50_categorical_accuracy: 0.9622 - factorized_top_k/top_100_categorical_accuracy: 0.9866 - loss: 2149.5369 - regularization_loss: 0.0000e+00 - total_loss: 2149.5369 - val_root_mean_squared_error: 1.6963 - val_factorized_top_k/top_1_categorical_accuracy: 0.0291 - val_factorized_top_k/top_5_categorical_accuracy: 0.0485 - val_factorized_top_k/top_10_categorical_accuracy: 0.0534 - val_factorized_top_k/top_50_categorical_accuracy: 0.1505 - val_factorized_top_k/top_100_categorical_accuracy: 0.2379 - val_loss: 2494.7212 - val_regularization_loss: 0.0000e+00 - val_total_loss: 2494.7212
# Epoch 14/100
# 1/1 [==============================] - 0s 165ms/step - root_mean_squared_error: 1.7962 - factorized_top_k/top_1_categorical_accuracy: 0.4768 - factorized_top_k/top_5_categorical_accuracy: 0.8915 - factorized_top_k/top_10_categorical_accuracy: 0.9244 - factorized_top_k/top_50_categorical_accuracy: 0.9793 - factorized_top_k/top_100_categorical_accuracy: 0.9927 - loss: 1490.9358 - regularization_loss: 0.0000e+00 - total_loss: 1490.9358 - val_root_mean_squared_error: 1.5763 - val_factorized_top_k/top_1_categorical_accuracy: 0.0243 - val_factorized_top_k/top_5_categorical_accuracy: 0.0485 - val_factorized_top_k/top_10_categorical_accuracy: 0.0534 - val_factorized_top_k/top_50_categorical_accuracy: 0.1553 - val_factorized_top_k/top_100_categorical_accuracy: 0.2330 - val_loss: 2461.5979 - val_regularization_loss: 0.0000e+00 - val_total_loss: 2461.5979
# Epoch 15/100
# 1/1 [==============================] - 0s 160ms/step - root_mean_squared_error: 1.4912 - factorized_top_k/top_1_categorical_accuracy: 0.4683 - factorized_top_k/top_5_categorical_accuracy: 0.9232 - factorized_top_k/top_10_categorical_accuracy: 0.9402 - factorized_top_k/top_50_categorical_accuracy: 0.9829 - factorized_top_k/top_100_categorical_accuracy: 0.9963 - loss: 1262.0156 - regularization_loss: 0.0000e+00 - total_loss: 1262.0156 - val_root_mean_squared_error: 1.3459 - val_factorized_top_k/top_1_categorical_accuracy: 0.0243 - val_factorized_top_k/top_5_categorical_accuracy: 0.0437 - val_factorized_top_k/top_10_categorical_accuracy: 0.0583 - val_factorized_top_k/top_50_categorical_accuracy: 0.1505 - val_factorized_top_k/top_100_categorical_accuracy: 0.2379 - val_loss: 2444.4395 - val_regularization_loss: 0.0000e+00 - val_total_loss: 2444.4395
# Epoch 16/100
# 1/1 [==============================] - 0s 164ms/step - root_mean_squared_error: 1.3502 - factorized_top_k/top_1_categorical_accuracy: 0.3878 - factorized_top_k/top_5_categorical_accuracy: 0.9415 - factorized_top_k/top_10_categorical_accuracy: 0.9524 - factorized_top_k/top_50_categorical_accuracy: 0.9878 - factorized_top_k/top_100_categorical_accuracy: 0.9976 - loss: 1153.4893 - regularization_loss: 0.0000e+00 - total_loss: 1153.4893 - val_root_mean_squared_error: 1.4225 - val_factorized_top_k/top_1_categorical_accuracy: 0.0243 - val_factorized_top_k/top_5_categorical_accuracy: 0.0437 - val_factorized_top_k/top_10_categorical_accuracy: 0.0583 - val_factorized_top_k/top_50_categorical_accuracy: 0.1553 - val_factorized_top_k/top_100_categorical_accuracy: 0.2330 - val_loss: 2455.2148 - val_regularization_loss: 0.0000e+00 - val_total_loss: 2455.2148
# Epoch 17/100
# 1/1 [==============================] - 0s 168ms/step - root_mean_squared_error: 1.2637 - factorized_top_k/top_1_categorical_accuracy: 0.3293 - factorized_top_k/top_5_categorical_accuracy: 0.9524 - factorized_top_k/top_10_categorical_accuracy: 0.9634 - factorized_top_k/top_50_categorical_accuracy: 0.9890 - factorized_top_k/top_100_categorical_accuracy: 0.9988 - loss: 1080.1041 - regularization_loss: 0.0000e+00 - total_loss: 1080.1041 - val_root_mean_squared_error: 1.2106 - val_factorized_top_k/top_1_categorical_accuracy: 0.0194 - val_factorized_top_k/top_5_categorical_accuracy: 0.0437 - val_factorized_top_k/top_10_categorical_accuracy: 0.0534 - val_factorized_top_k/top_50_categorical_accuracy: 0.1553 - val_factorized_top_k/top_100_categorical_accuracy: 0.2330 - val_loss: 2459.7407 - val_regularization_loss: 0.0000e+00 - val_total_loss: 2459.7407
# Epoch 18/100
# 1/1 [==============================] - 0s 176ms/step - root_mean_squared_error: 1.1881 - factorized_top_k/top_1_categorical_accuracy: 0.2476 - factorized_top_k/top_5_categorical_accuracy: 0.9610 - factorized_top_k/top_10_categorical_accuracy: 0.9707 - factorized_top_k/top_50_categorical_accuracy: 0.9927 - factorized_top_k/top_100_categorical_accuracy: 0.9988 - loss: 1024.3524 - regularization_loss: 0.0000e+00 - total_loss: 1024.3524 - val_root_mean_squared_error: 1.3398 - val_factorized_top_k/top_1_categorical_accuracy: 0.0340 - val_factorized_top_k/top_5_categorical_accuracy: 0.0437 - val_factorized_top_k/top_10_categorical_accuracy: 0.0631 - val_factorized_top_k/top_50_categorical_accuracy: 0.1505 - val_factorized_top_k/top_100_categorical_accuracy: 0.2330 - val_loss: 2480.1516 - val_regularization_loss: 0.0000e+00 - val_total_loss: 2480.1516
# Epoch 19/100
# 1/1 [==============================] - 0s 186ms/step - root_mean_squared_error: 1.1425 - factorized_top_k/top_1_categorical_accuracy: 0.2183 - factorized_top_k/top_5_categorical_accuracy: 0.9610 - factorized_top_k/top_10_categorical_accuracy: 0.9780 - factorized_top_k/top_50_categorical_accuracy: 0.9951 - factorized_top_k/top_100_categorical_accuracy: 0.9988 - loss: 979.1761 - regularization_loss: 0.0000e+00 - total_loss: 979.1761 - val_root_mean_squared_error: 1.1229 - val_factorized_top_k/top_1_categorical_accuracy: 0.0291 - val_factorized_top_k/top_5_categorical_accuracy: 0.0485 - val_factorized_top_k/top_10_categorical_accuracy: 0.0631 - val_factorized_top_k/top_50_categorical_accuracy: 0.1505 - val_factorized_top_k/top_100_categorical_accuracy: 0.2330 - val_loss: 2490.8972 - val_regularization_loss: 0.0000e+00 - val_total_loss: 2490.8972
# Epoch 20/100
# 1/1 [==============================] - 0s 164ms/step - root_mean_squared_error: 1.0869 - factorized_top_k/top_1_categorical_accuracy: 0.1549 - factorized_top_k/top_5_categorical_accuracy: 0.9707 - factorized_top_k/top_10_categorical_accuracy: 0.9817 - factorized_top_k/top_50_categorical_accuracy: 0.9963 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 942.0869 - regularization_loss: 0.0000e+00 - total_loss: 942.0869 - val_root_mean_squared_error: 1.2839 - val_factorized_top_k/top_1_categorical_accuracy: 0.0340 - val_factorized_top_k/top_5_categorical_accuracy: 0.0485 - val_factorized_top_k/top_10_categorical_accuracy: 0.0680 - val_factorized_top_k/top_50_categorical_accuracy: 0.1456 - val_factorized_top_k/top_100_categorical_accuracy: 0.2379 - val_loss: 2514.1843 - val_regularization_loss: 0.0000e+00 - val_total_loss: 2514.1843
# Epoch 21/100
# 1/1 [==============================] - 0s 162ms/step - root_mean_squared_error: 1.0590 - factorized_top_k/top_1_categorical_accuracy: 0.1744 - factorized_top_k/top_5_categorical_accuracy: 0.9780 - factorized_top_k/top_10_categorical_accuracy: 0.9878 - factorized_top_k/top_50_categorical_accuracy: 0.9976 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 911.5419 - regularization_loss: 0.0000e+00 - total_loss: 911.5419 - val_root_mean_squared_error: 1.0631 - val_factorized_top_k/top_1_categorical_accuracy: 0.0243 - val_factorized_top_k/top_5_categorical_accuracy: 0.0534 - val_factorized_top_k/top_10_categorical_accuracy: 0.0680 - val_factorized_top_k/top_50_categorical_accuracy: 0.1456 - val_factorized_top_k/top_100_categorical_accuracy: 0.2379 - val_loss: 2526.5137 - val_regularization_loss: 0.0000e+00 - val_total_loss: 2526.5137
# Epoch 22/100
# 1/1 [==============================] - 0s 194ms/step - root_mean_squared_error: 1.0106 - factorized_top_k/top_1_categorical_accuracy: 0.1195 - factorized_top_k/top_5_categorical_accuracy: 0.9841 - factorized_top_k/top_10_categorical_accuracy: 0.9927 - factorized_top_k/top_50_categorical_accuracy: 0.9988 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 884.7188 - regularization_loss: 0.0000e+00 - total_loss: 884.7188 - val_root_mean_squared_error: 1.2412 - val_factorized_top_k/top_1_categorical_accuracy: 0.0340 - val_factorized_top_k/top_5_categorical_accuracy: 0.0534 - val_factorized_top_k/top_10_categorical_accuracy: 0.0728 - val_factorized_top_k/top_50_categorical_accuracy: 0.1408 - val_factorized_top_k/top_100_categorical_accuracy: 0.2330 - val_loss: 2550.1831 - val_regularization_loss: 0.0000e+00 - val_total_loss: 2550.1831
# Epoch 23/100
# 1/1 [==============================] - 0s 171ms/step - root_mean_squared_error: 0.9928 - factorized_top_k/top_1_categorical_accuracy: 0.1476 - factorized_top_k/top_5_categorical_accuracy: 0.9890 - factorized_top_k/top_10_categorical_accuracy: 0.9927 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 861.1729 - regularization_loss: 0.0000e+00 - total_loss: 861.1729 - val_root_mean_squared_error: 1.0221 - val_factorized_top_k/top_1_categorical_accuracy: 0.0194 - val_factorized_top_k/top_5_categorical_accuracy: 0.0534 - val_factorized_top_k/top_10_categorical_accuracy: 0.0777 - val_factorized_top_k/top_50_categorical_accuracy: 0.1408 - val_factorized_top_k/top_100_categorical_accuracy: 0.2379 - val_loss: 2562.4846 - val_regularization_loss: 0.0000e+00 - val_total_loss: 2562.4846
# Epoch 24/100
# 1/1 [==============================] - 0s 181ms/step - root_mean_squared_error: 0.9479 - factorized_top_k/top_1_categorical_accuracy: 0.0829 - factorized_top_k/top_5_categorical_accuracy: 0.9927 - factorized_top_k/top_10_categorical_accuracy: 0.9927 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 840.7908 - regularization_loss: 0.0000e+00 - total_loss: 840.7908 - val_root_mean_squared_error: 1.2051 - val_factorized_top_k/top_1_categorical_accuracy: 0.0194 - val_factorized_top_k/top_5_categorical_accuracy: 0.0534 - val_factorized_top_k/top_10_categorical_accuracy: 0.0777 - val_factorized_top_k/top_50_categorical_accuracy: 0.1408 - val_factorized_top_k/top_100_categorical_accuracy: 0.2427 - val_loss: 2586.2483 - val_regularization_loss: 0.0000e+00 - val_total_loss: 2586.2483
# Epoch 25/100
# 1/1 [==============================] - 0s 178ms/step - root_mean_squared_error: 0.9363 - factorized_top_k/top_1_categorical_accuracy: 0.1354 - factorized_top_k/top_5_categorical_accuracy: 0.9927 - factorized_top_k/top_10_categorical_accuracy: 0.9927 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 823.3658 - regularization_loss: 0.0000e+00 - total_loss: 823.3658 - val_root_mean_squared_error: 0.9915 - val_factorized_top_k/top_1_categorical_accuracy: 0.0291 - val_factorized_top_k/top_5_categorical_accuracy: 0.0534 - val_factorized_top_k/top_10_categorical_accuracy: 0.0728 - val_factorized_top_k/top_50_categorical_accuracy: 0.1408 - val_factorized_top_k/top_100_categorical_accuracy: 0.2379 - val_loss: 2598.4102 - val_regularization_loss: 0.0000e+00 - val_total_loss: 2598.4102
# Epoch 26/100
# 1/1 [==============================] - 0s 164ms/step - root_mean_squared_error: 0.8953 - factorized_top_k/top_1_categorical_accuracy: 0.0756 - factorized_top_k/top_5_categorical_accuracy: 0.9927 - factorized_top_k/top_10_categorical_accuracy: 0.9927 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 808.3079 - regularization_loss: 0.0000e+00 - total_loss: 808.3079 - val_root_mean_squared_error: 1.1754 - val_factorized_top_k/top_1_categorical_accuracy: 0.0291 - val_factorized_top_k/top_5_categorical_accuracy: 0.0534 - val_factorized_top_k/top_10_categorical_accuracy: 0.0777 - val_factorized_top_k/top_50_categorical_accuracy: 0.1408 - val_factorized_top_k/top_100_categorical_accuracy: 0.2379 - val_loss: 2621.9453 - val_regularization_loss: 0.0000e+00 - val_total_loss: 2621.9453
# Epoch 27/100
# 1/1 [==============================] - 0s 170ms/step - root_mean_squared_error: 0.8886 - factorized_top_k/top_1_categorical_accuracy: 0.1305 - factorized_top_k/top_5_categorical_accuracy: 0.9927 - factorized_top_k/top_10_categorical_accuracy: 0.9963 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 795.6393 - regularization_loss: 0.0000e+00 - total_loss: 795.6393 - val_root_mean_squared_error: 0.9685 - val_factorized_top_k/top_1_categorical_accuracy: 0.0388 - val_factorized_top_k/top_5_categorical_accuracy: 0.0534 - val_factorized_top_k/top_10_categorical_accuracy: 0.0728 - val_factorized_top_k/top_50_categorical_accuracy: 0.1408 - val_factorized_top_k/top_100_categorical_accuracy: 0.2379 - val_loss: 2633.6667 - val_regularization_loss: 0.0000e+00 - val_total_loss: 2633.6667
# Epoch 28/100
# 1/1 [==============================] - 0s 187ms/step - root_mean_squared_error: 0.8517 - factorized_top_k/top_1_categorical_accuracy: 0.0805 - factorized_top_k/top_5_categorical_accuracy: 0.9939 - factorized_top_k/top_10_categorical_accuracy: 0.9963 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 784.4087 - regularization_loss: 0.0000e+00 - total_loss: 784.4087 - val_root_mean_squared_error: 1.1522 - val_factorized_top_k/top_1_categorical_accuracy: 0.0340 - val_factorized_top_k/top_5_categorical_accuracy: 0.0534 - val_factorized_top_k/top_10_categorical_accuracy: 0.0777 - val_factorized_top_k/top_50_categorical_accuracy: 0.1408 - val_factorized_top_k/top_100_categorical_accuracy: 0.2379 - val_loss: 2656.6079 - val_regularization_loss: 0.0000e+00 - val_total_loss: 2656.6079
# Epoch 29/100
# 1/1 [==============================] - 0s 175ms/step - root_mean_squared_error: 0.8492 - factorized_top_k/top_1_categorical_accuracy: 0.1244 - factorized_top_k/top_5_categorical_accuracy: 0.9951 - factorized_top_k/top_10_categorical_accuracy: 0.9976 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 774.9640 - regularization_loss: 0.0000e+00 - total_loss: 774.9640 - val_root_mean_squared_error: 0.9512 - val_factorized_top_k/top_1_categorical_accuracy: 0.0243 - val_factorized_top_k/top_5_categorical_accuracy: 0.0534 - val_factorized_top_k/top_10_categorical_accuracy: 0.0777 - val_factorized_top_k/top_50_categorical_accuracy: 0.1408 - val_factorized_top_k/top_100_categorical_accuracy: 0.2379 - val_loss: 2667.4524 - val_regularization_loss: 0.0000e+00 - val_total_loss: 2667.4524
# Epoch 30/100
# 1/1 [==============================] - 0s 175ms/step - root_mean_squared_error: 0.8155 - factorized_top_k/top_1_categorical_accuracy: 0.0805 - factorized_top_k/top_5_categorical_accuracy: 0.9963 - factorized_top_k/top_10_categorical_accuracy: 0.9976 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 766.2106 - regularization_loss: 0.0000e+00 - total_loss: 766.2106 - val_root_mean_squared_error: 1.1344 - val_factorized_top_k/top_1_categorical_accuracy: 0.0243 - val_factorized_top_k/top_5_categorical_accuracy: 0.0534 - val_factorized_top_k/top_10_categorical_accuracy: 0.0777 - val_factorized_top_k/top_50_categorical_accuracy: 0.1456 - val_factorized_top_k/top_100_categorical_accuracy: 0.2379 - val_loss: 2689.6226 - val_regularization_loss: 0.0000e+00 - val_total_loss: 2689.6226
# Epoch 31/100
# 1/1 [==============================] - 0s 166ms/step - root_mean_squared_error: 0.8170 - factorized_top_k/top_1_categorical_accuracy: 0.1317 - factorized_top_k/top_5_categorical_accuracy: 0.9963 - factorized_top_k/top_10_categorical_accuracy: 0.9976 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 758.8577 - regularization_loss: 0.0000e+00 - total_loss: 758.8577 - val_root_mean_squared_error: 0.9392 - val_factorized_top_k/top_1_categorical_accuracy: 0.0243 - val_factorized_top_k/top_5_categorical_accuracy: 0.0534 - val_factorized_top_k/top_10_categorical_accuracy: 0.0728 - val_factorized_top_k/top_50_categorical_accuracy: 0.1505 - val_factorized_top_k/top_100_categorical_accuracy: 0.2330 - val_loss: 2699.2886 - val_regularization_loss: 0.0000e+00 - val_total_loss: 2699.2886
# Epoch 32/100
# 1/1 [==============================] - 0s 165ms/step - root_mean_squared_error: 0.7848 - factorized_top_k/top_1_categorical_accuracy: 0.0927 - factorized_top_k/top_5_categorical_accuracy: 0.9963 - factorized_top_k/top_10_categorical_accuracy: 0.9976 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 751.7242 - regularization_loss: 0.0000e+00 - total_loss: 751.7242 - val_root_mean_squared_error: 1.1205 - val_factorized_top_k/top_1_categorical_accuracy: 0.0291 - val_factorized_top_k/top_5_categorical_accuracy: 0.0534 - val_factorized_top_k/top_10_categorical_accuracy: 0.0777 - val_factorized_top_k/top_50_categorical_accuracy: 0.1456 - val_factorized_top_k/top_100_categorical_accuracy: 0.2379 - val_loss: 2720.8120 - val_regularization_loss: 0.0000e+00 - val_total_loss: 2720.8120
# Epoch 33/100
# 1/1 [==============================] - 0s 171ms/step - root_mean_squared_error: 0.7894 - factorized_top_k/top_1_categorical_accuracy: 0.1488 - factorized_top_k/top_5_categorical_accuracy: 0.9963 - factorized_top_k/top_10_categorical_accuracy: 0.9988 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 745.8338 - regularization_loss: 0.0000e+00 - total_loss: 745.8338 - val_root_mean_squared_error: 0.9307 - val_factorized_top_k/top_1_categorical_accuracy: 0.0194 - val_factorized_top_k/top_5_categorical_accuracy: 0.0583 - val_factorized_top_k/top_10_categorical_accuracy: 0.0728 - val_factorized_top_k/top_50_categorical_accuracy: 0.1456 - val_factorized_top_k/top_100_categorical_accuracy: 0.2330 - val_loss: 2729.1882 - val_regularization_loss: 0.0000e+00 - val_total_loss: 2729.1882
# Epoch 34/100
# 1/1 [==============================] - 0s 171ms/step - root_mean_squared_error: 0.7577 - factorized_top_k/top_1_categorical_accuracy: 0.0951 - factorized_top_k/top_5_categorical_accuracy: 0.9976 - factorized_top_k/top_10_categorical_accuracy: 0.9988 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 739.9855 - regularization_loss: 0.0000e+00 - total_loss: 739.9855 - val_root_mean_squared_error: 1.1081 - val_factorized_top_k/top_1_categorical_accuracy: 0.0243 - val_factorized_top_k/top_5_categorical_accuracy: 0.0534 - val_factorized_top_k/top_10_categorical_accuracy: 0.0777 - val_factorized_top_k/top_50_categorical_accuracy: 0.1456 - val_factorized_top_k/top_100_categorical_accuracy: 0.2330 - val_loss: 2750.2375 - val_regularization_loss: 0.0000e+00 - val_total_loss: 2750.2375
# Epoch 35/100
# 1/1 [==============================] - 0s 171ms/step - root_mean_squared_error: 0.7638 - factorized_top_k/top_1_categorical_accuracy: 0.1732 - factorized_top_k/top_5_categorical_accuracy: 0.9988 - factorized_top_k/top_10_categorical_accuracy: 0.9988 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 735.2426 - regularization_loss: 0.0000e+00 - total_loss: 735.2426 - val_root_mean_squared_error: 0.9243 - val_factorized_top_k/top_1_categorical_accuracy: 0.0194 - val_factorized_top_k/top_5_categorical_accuracy: 0.0583 - val_factorized_top_k/top_10_categorical_accuracy: 0.0728 - val_factorized_top_k/top_50_categorical_accuracy: 0.1456 - val_factorized_top_k/top_100_categorical_accuracy: 0.2330 - val_loss: 2757.4275 - val_regularization_loss: 0.0000e+00 - val_total_loss: 2757.4275
# Epoch 36/100
# 1/1 [==============================] - 0s 168ms/step - root_mean_squared_error: 0.7332 - factorized_top_k/top_1_categorical_accuracy: 0.0976 - factorized_top_k/top_5_categorical_accuracy: 0.9988 - factorized_top_k/top_10_categorical_accuracy: 0.9988 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 730.3508 - regularization_loss: 0.0000e+00 - total_loss: 730.3508 - val_root_mean_squared_error: 1.0980 - val_factorized_top_k/top_1_categorical_accuracy: 0.0388 - val_factorized_top_k/top_5_categorical_accuracy: 0.0534 - val_factorized_top_k/top_10_categorical_accuracy: 0.0777 - val_factorized_top_k/top_50_categorical_accuracy: 0.1456 - val_factorized_top_k/top_100_categorical_accuracy: 0.2379 - val_loss: 2777.8647 - val_regularization_loss: 0.0000e+00 - val_total_loss: 2777.8647
# Epoch 37/100
# 1/1 [==============================] - 0s 185ms/step - root_mean_squared_error: 0.7415 - factorized_top_k/top_1_categorical_accuracy: 0.1756 - factorized_top_k/top_5_categorical_accuracy: 0.9988 - factorized_top_k/top_10_categorical_accuracy: 0.9988 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 726.2950 - regularization_loss: 0.0000e+00 - total_loss: 726.2950 - val_root_mean_squared_error: 0.9191 - val_factorized_top_k/top_1_categorical_accuracy: 0.0388 - val_factorized_top_k/top_5_categorical_accuracy: 0.0583 - val_factorized_top_k/top_10_categorical_accuracy: 0.0777 - val_factorized_top_k/top_50_categorical_accuracy: 0.1505 - val_factorized_top_k/top_100_categorical_accuracy: 0.2379 - val_loss: 2784.2920 - val_regularization_loss: 0.0000e+00 - val_total_loss: 2784.2920
# Epoch 38/100
# 1/1 [==============================] - 0s 165ms/step - root_mean_squared_error: 0.7112 - factorized_top_k/top_1_categorical_accuracy: 0.1085 - factorized_top_k/top_5_categorical_accuracy: 0.9988 - factorized_top_k/top_10_categorical_accuracy: 0.9988 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 722.0020 - regularization_loss: 0.0000e+00 - total_loss: 722.0020 - val_root_mean_squared_error: 1.0885 - val_factorized_top_k/top_1_categorical_accuracy: 0.0388 - val_factorized_top_k/top_5_categorical_accuracy: 0.0583 - val_factorized_top_k/top_10_categorical_accuracy: 0.0777 - val_factorized_top_k/top_50_categorical_accuracy: 0.1456 - val_factorized_top_k/top_100_categorical_accuracy: 0.2330 - val_loss: 2803.8313 - val_regularization_loss: 0.0000e+00 - val_total_loss: 2803.8313
# Epoch 39/100
# 1/1 [==============================] - 0s 163ms/step - root_mean_squared_error: 0.7203 - factorized_top_k/top_1_categorical_accuracy: 0.1866 - factorized_top_k/top_5_categorical_accuracy: 0.9988 - factorized_top_k/top_10_categorical_accuracy: 0.9988 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 718.3992 - regularization_loss: 0.0000e+00 - total_loss: 718.3992 - val_root_mean_squared_error: 0.9144 - val_factorized_top_k/top_1_categorical_accuracy: 0.0291 - val_factorized_top_k/top_5_categorical_accuracy: 0.0583 - val_factorized_top_k/top_10_categorical_accuracy: 0.0777 - val_factorized_top_k/top_50_categorical_accuracy: 0.1505 - val_factorized_top_k/top_100_categorical_accuracy: 0.2330 - val_loss: 2809.9285 - val_regularization_loss: 0.0000e+00 - val_total_loss: 2809.9285
# Epoch 40/100
# 1/1 [==============================] - 0s 168ms/step - root_mean_squared_error: 0.6901 - factorized_top_k/top_1_categorical_accuracy: 0.1073 - factorized_top_k/top_5_categorical_accuracy: 0.9988 - factorized_top_k/top_10_categorical_accuracy: 0.9988 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 714.6072 - regularization_loss: 0.0000e+00 - total_loss: 714.6072 - val_root_mean_squared_error: 1.0793 - val_factorized_top_k/top_1_categorical_accuracy: 0.0388 - val_factorized_top_k/top_5_categorical_accuracy: 0.0583 - val_factorized_top_k/top_10_categorical_accuracy: 0.0777 - val_factorized_top_k/top_50_categorical_accuracy: 0.1456 - val_factorized_top_k/top_100_categorical_accuracy: 0.2379 - val_loss: 2828.3848 - val_regularization_loss: 0.0000e+00 - val_total_loss: 2828.3848
# Epoch 41/100
# 1/1 [==============================] - 0s 178ms/step - root_mean_squared_error: 0.6993 - factorized_top_k/top_1_categorical_accuracy: 0.1915 - factorized_top_k/top_5_categorical_accuracy: 0.9988 - factorized_top_k/top_10_categorical_accuracy: 0.9988 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 711.3826 - regularization_loss: 0.0000e+00 - total_loss: 711.3826 - val_root_mean_squared_error: 0.9105 - val_factorized_top_k/top_1_categorical_accuracy: 0.0291 - val_factorized_top_k/top_5_categorical_accuracy: 0.0583 - val_factorized_top_k/top_10_categorical_accuracy: 0.0777 - val_factorized_top_k/top_50_categorical_accuracy: 0.1505 - val_factorized_top_k/top_100_categorical_accuracy: 0.2330 - val_loss: 2834.4531 - val_regularization_loss: 0.0000e+00 - val_total_loss: 2834.4531
# Epoch 42/100
# 1/1 [==============================] - 0s 174ms/step - root_mean_squared_error: 0.6693 - factorized_top_k/top_1_categorical_accuracy: 0.1061 - factorized_top_k/top_5_categorical_accuracy: 0.9988 - factorized_top_k/top_10_categorical_accuracy: 0.9988 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 708.0375 - regularization_loss: 0.0000e+00 - total_loss: 708.0375 - val_root_mean_squared_error: 1.0688 - val_factorized_top_k/top_1_categorical_accuracy: 0.0388 - val_factorized_top_k/top_5_categorical_accuracy: 0.0583 - val_factorized_top_k/top_10_categorical_accuracy: 0.0777 - val_factorized_top_k/top_50_categorical_accuracy: 0.1456 - val_factorized_top_k/top_100_categorical_accuracy: 0.2330 - val_loss: 2851.6885 - val_regularization_loss: 0.0000e+00 - val_total_loss: 2851.6885
# Epoch 43/100
# 1/1 [==============================] - 0s 174ms/step - root_mean_squared_error: 0.6772 - factorized_top_k/top_1_categorical_accuracy: 0.1902 - factorized_top_k/top_5_categorical_accuracy: 0.9988 - factorized_top_k/top_10_categorical_accuracy: 0.9988 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 705.1658 - regularization_loss: 0.0000e+00 - total_loss: 705.1658 - val_root_mean_squared_error: 0.9070 - val_factorized_top_k/top_1_categorical_accuracy: 0.0243 - val_factorized_top_k/top_5_categorical_accuracy: 0.0583 - val_factorized_top_k/top_10_categorical_accuracy: 0.0777 - val_factorized_top_k/top_50_categorical_accuracy: 0.1505 - val_factorized_top_k/top_100_categorical_accuracy: 0.2330 - val_loss: 2857.9446 - val_regularization_loss: 0.0000e+00 - val_total_loss: 2857.9446
# Epoch 44/100
# 1/1 [==============================] - 0s 165ms/step - root_mean_squared_error: 0.6487 - factorized_top_k/top_1_categorical_accuracy: 0.1000 - factorized_top_k/top_5_categorical_accuracy: 0.9988 - factorized_top_k/top_10_categorical_accuracy: 0.9988 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 702.2361 - regularization_loss: 0.0000e+00 - total_loss: 702.2361 - val_root_mean_squared_error: 1.0583 - val_factorized_top_k/top_1_categorical_accuracy: 0.0194 - val_factorized_top_k/top_5_categorical_accuracy: 0.0583 - val_factorized_top_k/top_10_categorical_accuracy: 0.0777 - val_factorized_top_k/top_50_categorical_accuracy: 0.1505 - val_factorized_top_k/top_100_categorical_accuracy: 0.2330 - val_loss: 2873.8501 - val_regularization_loss: 0.0000e+00 - val_total_loss: 2873.8501
# Epoch 45/100
# 1/1 [==============================] - 0s 189ms/step - root_mean_squared_error: 0.6558 - factorized_top_k/top_1_categorical_accuracy: 0.1817 - factorized_top_k/top_5_categorical_accuracy: 0.9988 - factorized_top_k/top_10_categorical_accuracy: 1.0000 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 699.7043 - regularization_loss: 0.0000e+00 - total_loss: 699.7043 - val_root_mean_squared_error: 0.9040 - val_factorized_top_k/top_1_categorical_accuracy: 0.0291 - val_factorized_top_k/top_5_categorical_accuracy: 0.0583 - val_factorized_top_k/top_10_categorical_accuracy: 0.0777 - val_factorized_top_k/top_50_categorical_accuracy: 0.1505 - val_factorized_top_k/top_100_categorical_accuracy: 0.2379 - val_loss: 2880.4592 - val_regularization_loss: 0.0000e+00 - val_total_loss: 2880.4592
# Epoch 46/100
# 1/1 [==============================] - 0s 172ms/step - root_mean_squared_error: 0.6292 - factorized_top_k/top_1_categorical_accuracy: 0.0976 - factorized_top_k/top_5_categorical_accuracy: 0.9988 - factorized_top_k/top_10_categorical_accuracy: 1.0000 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 697.1550 - regularization_loss: 0.0000e+00 - total_loss: 697.1550 - val_root_mean_squared_error: 1.0498 - val_factorized_top_k/top_1_categorical_accuracy: 0.0485 - val_factorized_top_k/top_5_categorical_accuracy: 0.0583 - val_factorized_top_k/top_10_categorical_accuracy: 0.0777 - val_factorized_top_k/top_50_categorical_accuracy: 0.1505 - val_factorized_top_k/top_100_categorical_accuracy: 0.2379 - val_loss: 2894.9377 - val_regularization_loss: 0.0000e+00 - val_total_loss: 2894.9377
# Epoch 47/100
# 1/1 [==============================] - 0s 166ms/step - root_mean_squared_error: 0.6368 - factorized_top_k/top_1_categorical_accuracy: 0.1732 - factorized_top_k/top_5_categorical_accuracy: 0.9988 - factorized_top_k/top_10_categorical_accuracy: 1.0000 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 694.9424 - regularization_loss: 0.0000e+00 - total_loss: 694.9424 - val_root_mean_squared_error: 0.9014 - val_factorized_top_k/top_1_categorical_accuracy: 0.0388 - val_factorized_top_k/top_5_categorical_accuracy: 0.0583 - val_factorized_top_k/top_10_categorical_accuracy: 0.0777 - val_factorized_top_k/top_50_categorical_accuracy: 0.1505 - val_factorized_top_k/top_100_categorical_accuracy: 0.2379 - val_loss: 2902.0601 - val_regularization_loss: 0.0000e+00 - val_total_loss: 2902.0601
# Epoch 48/100
# 1/1 [==============================] - 0s 216ms/step - root_mean_squared_error: 0.6113 - factorized_top_k/top_1_categorical_accuracy: 0.0951 - factorized_top_k/top_5_categorical_accuracy: 0.9988 - factorized_top_k/top_10_categorical_accuracy: 1.0000 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 692.7331 - regularization_loss: 0.0000e+00 - total_loss: 692.7331 - val_root_mean_squared_error: 1.0412 - val_factorized_top_k/top_1_categorical_accuracy: 0.0194 - val_factorized_top_k/top_5_categorical_accuracy: 0.0583 - val_factorized_top_k/top_10_categorical_accuracy: 0.0777 - val_factorized_top_k/top_50_categorical_accuracy: 0.1456 - val_factorized_top_k/top_100_categorical_accuracy: 0.2379 - val_loss: 2914.9841 - val_regularization_loss: 0.0000e+00 - val_total_loss: 2914.9841
# Epoch 49/100
# 1/1 [==============================] - 0s 276ms/step - root_mean_squared_error: 0.6180 - factorized_top_k/top_1_categorical_accuracy: 0.1549 - factorized_top_k/top_5_categorical_accuracy: 0.9988 - factorized_top_k/top_10_categorical_accuracy: 1.0000 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 690.8161 - regularization_loss: 0.0000e+00 - total_loss: 690.8161 - val_root_mean_squared_error: 0.8990 - val_factorized_top_k/top_1_categorical_accuracy: 0.0340 - val_factorized_top_k/top_5_categorical_accuracy: 0.0583 - val_factorized_top_k/top_10_categorical_accuracy: 0.0777 - val_factorized_top_k/top_50_categorical_accuracy: 0.1505 - val_factorized_top_k/top_100_categorical_accuracy: 0.2427 - val_loss: 2922.7898 - val_regularization_loss: 0.0000e+00 - val_total_loss: 2922.7898
# Epoch 50/100
# 1/1 [==============================] - 0s 217ms/step - root_mean_squared_error: 0.5947 - factorized_top_k/top_1_categorical_accuracy: 0.0939 - factorized_top_k/top_5_categorical_accuracy: 1.0000 - factorized_top_k/top_10_categorical_accuracy: 1.0000 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 688.9167 - regularization_loss: 0.0000e+00 - total_loss: 688.9167 - val_root_mean_squared_error: 1.0339 - val_factorized_top_k/top_1_categorical_accuracy: 0.0340 - val_factorized_top_k/top_5_categorical_accuracy: 0.0583 - val_factorized_top_k/top_10_categorical_accuracy: 0.0777 - val_factorized_top_k/top_50_categorical_accuracy: 0.1456 - val_factorized_top_k/top_100_categorical_accuracy: 0.2427 - val_loss: 2934.0408 - val_regularization_loss: 0.0000e+00 - val_total_loss: 2934.0408
# Epoch 51/100
# 1/1 [==============================] - 0s 226ms/step - root_mean_squared_error: 0.6012 - factorized_top_k/top_1_categorical_accuracy: 0.1537 - factorized_top_k/top_5_categorical_accuracy: 1.0000 - factorized_top_k/top_10_categorical_accuracy: 1.0000 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 687.2743 - regularization_loss: 0.0000e+00 - total_loss: 687.2743 - val_root_mean_squared_error: 0.8969 - val_factorized_top_k/top_1_categorical_accuracy: 0.0340 - val_factorized_top_k/top_5_categorical_accuracy: 0.0583 - val_factorized_top_k/top_10_categorical_accuracy: 0.0777 - val_factorized_top_k/top_50_categorical_accuracy: 0.1456 - val_factorized_top_k/top_100_categorical_accuracy: 0.2427 - val_loss: 2942.5527 - val_regularization_loss: 0.0000e+00 - val_total_loss: 2942.5527
# Epoch 52/100
# 1/1 [==============================] - 0s 194ms/step - root_mean_squared_error: 0.5796 - factorized_top_k/top_1_categorical_accuracy: 0.0963 - factorized_top_k/top_5_categorical_accuracy: 1.0000 - factorized_top_k/top_10_categorical_accuracy: 1.0000 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 685.6041 - regularization_loss: 0.0000e+00 - total_loss: 685.6041 - val_root_mean_squared_error: 1.0280 - val_factorized_top_k/top_1_categorical_accuracy: 0.0340 - val_factorized_top_k/top_5_categorical_accuracy: 0.0583 - val_factorized_top_k/top_10_categorical_accuracy: 0.0777 - val_factorized_top_k/top_50_categorical_accuracy: 0.1456 - val_factorized_top_k/top_100_categorical_accuracy: 0.2427 - val_loss: 2952.2905 - val_regularization_loss: 0.0000e+00 - val_total_loss: 2952.2905
# Epoch 53/100
# 1/1 [==============================] - 0s 184ms/step - root_mean_squared_error: 0.5864 - factorized_top_k/top_1_categorical_accuracy: 0.1451 - factorized_top_k/top_5_categorical_accuracy: 1.0000 - factorized_top_k/top_10_categorical_accuracy: 1.0000 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 684.1304 - regularization_loss: 0.0000e+00 - total_loss: 684.1304 - val_root_mean_squared_error: 0.8950 - val_factorized_top_k/top_1_categorical_accuracy: 0.0340 - val_factorized_top_k/top_5_categorical_accuracy: 0.0583 - val_factorized_top_k/top_10_categorical_accuracy: 0.0777 - val_factorized_top_k/top_50_categorical_accuracy: 0.1505 - val_factorized_top_k/top_100_categorical_accuracy: 0.2427 - val_loss: 2961.1436 - val_regularization_loss: 0.0000e+00 - val_total_loss: 2961.1436
# Epoch 54/100
# 1/1 [==============================] - 0s 180ms/step - root_mean_squared_error: 0.5662 - factorized_top_k/top_1_categorical_accuracy: 0.0963 - factorized_top_k/top_5_categorical_accuracy: 1.0000 - factorized_top_k/top_10_categorical_accuracy: 1.0000 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 682.5396 - regularization_loss: 0.0000e+00 - total_loss: 682.5396 - val_root_mean_squared_error: 1.0229 - val_factorized_top_k/top_1_categorical_accuracy: 0.0291 - val_factorized_top_k/top_5_categorical_accuracy: 0.0583 - val_factorized_top_k/top_10_categorical_accuracy: 0.0777 - val_factorized_top_k/top_50_categorical_accuracy: 0.1456 - val_factorized_top_k/top_100_categorical_accuracy: 0.2427 - val_loss: 2969.9351 - val_regularization_loss: 0.0000e+00 - val_total_loss: 2969.9351
# Epoch 55/100
# 1/1 [==============================] - 0s 189ms/step - root_mean_squared_error: 0.5729 - factorized_top_k/top_1_categorical_accuracy: 0.1390 - factorized_top_k/top_5_categorical_accuracy: 1.0000 - factorized_top_k/top_10_categorical_accuracy: 1.0000 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 681.1466 - regularization_loss: 0.0000e+00 - total_loss: 681.1466 - val_root_mean_squared_error: 0.8929 - val_factorized_top_k/top_1_categorical_accuracy: 0.0291 - val_factorized_top_k/top_5_categorical_accuracy: 0.0583 - val_factorized_top_k/top_10_categorical_accuracy: 0.0777 - val_factorized_top_k/top_50_categorical_accuracy: 0.1505 - val_factorized_top_k/top_100_categorical_accuracy: 0.2427 - val_loss: 2978.7239 - val_regularization_loss: 0.0000e+00 - val_total_loss: 2978.7239
# Epoch 56/100
# ...
# Epoch 83/100
# 1/1 [==============================] - 0s 174ms/step - root_mean_squared_error: 0.4511 - factorized_top_k/top_1_categorical_accuracy: 0.0890 - factorized_top_k/top_5_categorical_accuracy: 1.0000 - factorized_top_k/top_10_categorical_accuracy: 1.0000 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 655.8460 - regularization_loss: 0.0000e+00 - total_loss: 655.8460 - val_root_mean_squared_error: 0.8626 - val_factorized_top_k/top_1_categorical_accuracy: 0.0243 - val_factorized_top_k/top_5_categorical_accuracy: 0.0583 - val_factorized_top_k/top_10_categorical_accuracy: 0.0777 - val_factorized_top_k/top_50_categorical_accuracy: 0.1456 - val_factorized_top_k/top_100_categorical_accuracy: 0.2427 - val_loss: 3169.3628 - val_regularization_loss: 0.0000e+00 - val_total_loss: 3169.3628
# Epoch 84/100
# 1/1 [==============================] - 0s 189ms/step - root_mean_squared_error: 0.4403 - factorized_top_k/top_1_categorical_accuracy: 0.0610 - factorized_top_k/top_5_categorical_accuracy: 1.0000 - factorized_top_k/top_10_categorical_accuracy: 1.0000 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 655.3173 - regularization_loss: 0.0000e+00 - total_loss: 655.3173 - val_root_mean_squared_error: 0.9724 - val_factorized_top_k/top_1_categorical_accuracy: 0.0243 - val_factorized_top_k/top_5_categorical_accuracy: 0.0583 - val_factorized_top_k/top_10_categorical_accuracy: 0.0777 - val_factorized_top_k/top_50_categorical_accuracy: 0.1408 - val_factorized_top_k/top_100_categorical_accuracy: 0.2427 - val_loss: 3176.8843 - val_regularization_loss: 0.0000e+00 - val_total_loss: 3176.8843
# Epoch 85/100
# 1/1 [==============================] - 0s 178ms/step - root_mean_squared_error: 0.4448 - factorized_top_k/top_1_categorical_accuracy: 0.0890 - factorized_top_k/top_5_categorical_accuracy: 1.0000 - factorized_top_k/top_10_categorical_accuracy: 1.0000 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 654.6906 - regularization_loss: 0.0000e+00 - total_loss: 654.6906 - val_root_mean_squared_error: 0.8609 - val_factorized_top_k/top_1_categorical_accuracy: 0.0194 - val_factorized_top_k/top_5_categorical_accuracy: 0.0583 - val_factorized_top_k/top_10_categorical_accuracy: 0.0777 - val_factorized_top_k/top_50_categorical_accuracy: 0.1408 - val_factorized_top_k/top_100_categorical_accuracy: 0.2427 - val_loss: 3180.4604 - val_regularization_loss: 0.0000e+00 - val_total_loss: 3180.4604
# Epoch 86/100
# 1/1 [==============================] - 0s 176ms/step - root_mean_squared_error: 0.4345 - factorized_top_k/top_1_categorical_accuracy: 0.0585 - factorized_top_k/top_5_categorical_accuracy: 1.0000 - factorized_top_k/top_10_categorical_accuracy: 1.0000 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 654.1803 - regularization_loss: 0.0000e+00 - total_loss: 654.1803 - val_root_mean_squared_error: 0.9700 - val_factorized_top_k/top_1_categorical_accuracy: 0.0340 - val_factorized_top_k/top_5_categorical_accuracy: 0.0583 - val_factorized_top_k/top_10_categorical_accuracy: 0.0777 - val_factorized_top_k/top_50_categorical_accuracy: 0.1408 - val_factorized_top_k/top_100_categorical_accuracy: 0.2427 - val_loss: 3187.6499 - val_regularization_loss: 0.0000e+00 - val_total_loss: 3187.6499
# Epoch 87/100
# 1/1 [==============================] - 0s 188ms/step - root_mean_squared_error: 0.4394 - factorized_top_k/top_1_categorical_accuracy: 0.0829 - factorized_top_k/top_5_categorical_accuracy: 1.0000 - factorized_top_k/top_10_categorical_accuracy: 1.0000 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 653.5838 - regularization_loss: 0.0000e+00 - total_loss: 653.5838 - val_root_mean_squared_error: 0.8586 - val_factorized_top_k/top_1_categorical_accuracy: 0.0291 - val_factorized_top_k/top_5_categorical_accuracy: 0.0583 - val_factorized_top_k/top_10_categorical_accuracy: 0.0777 - val_factorized_top_k/top_50_categorical_accuracy: 0.1456 - val_factorized_top_k/top_100_categorical_accuracy: 0.2427 - val_loss: 3191.3279 - val_regularization_loss: 0.0000e+00 - val_total_loss: 3191.3279
# Epoch 88/100
# 1/1 [==============================] - 0s 182ms/step - root_mean_squared_error: 0.4294 - factorized_top_k/top_1_categorical_accuracy: 0.0549 - factorized_top_k/top_5_categorical_accuracy: 1.0000 - factorized_top_k/top_10_categorical_accuracy: 1.0000 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 653.0928 - regularization_loss: 0.0000e+00 - total_loss: 653.0928 - val_root_mean_squared_error: 0.9677 - val_factorized_top_k/top_1_categorical_accuracy: 0.0485 - val_factorized_top_k/top_5_categorical_accuracy: 0.0583 - val_factorized_top_k/top_10_categorical_accuracy: 0.0777 - val_factorized_top_k/top_50_categorical_accuracy: 0.1408 - val_factorized_top_k/top_100_categorical_accuracy: 0.2427 - val_loss: 3198.1780 - val_regularization_loss: 0.0000e+00 - val_total_loss: 3198.1780
# Epoch 89/100
# 1/1 [==============================] - 0s 215ms/step - root_mean_squared_error: 0.4338 - factorized_top_k/top_1_categorical_accuracy: 0.0780 - factorized_top_k/top_5_categorical_accuracy: 1.0000 - factorized_top_k/top_10_categorical_accuracy: 1.0000 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 652.5239 - regularization_loss: 0.0000e+00 - total_loss: 652.5239 - val_root_mean_squared_error: 0.8567 - val_factorized_top_k/top_1_categorical_accuracy: 0.0340 - val_factorized_top_k/top_5_categorical_accuracy: 0.0583 - val_factorized_top_k/top_10_categorical_accuracy: 0.0777 - val_factorized_top_k/top_50_categorical_accuracy: 0.1456 - val_factorized_top_k/top_100_categorical_accuracy: 0.2427 - val_loss: 3201.9741 - val_regularization_loss: 0.0000e+00 - val_total_loss: 3201.9741
# Epoch 90/100
# 1/1 [==============================] - 0s 254ms/step - root_mean_squared_error: 0.4239 - factorized_top_k/top_1_categorical_accuracy: 0.0524 - factorized_top_k/top_5_categorical_accuracy: 1.0000 - factorized_top_k/top_10_categorical_accuracy: 1.0000 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 652.0521 - regularization_loss: 0.0000e+00 - total_loss: 652.0521 - val_root_mean_squared_error: 0.9650 - val_factorized_top_k/top_1_categorical_accuracy: 0.0340 - val_factorized_top_k/top_5_categorical_accuracy: 0.0583 - val_factorized_top_k/top_10_categorical_accuracy: 0.0777 - val_factorized_top_k/top_50_categorical_accuracy: 0.1408 - val_factorized_top_k/top_100_categorical_accuracy: 0.2427 - val_loss: 3208.4758 - val_regularization_loss: 0.0000e+00 - val_total_loss: 3208.4758
# Epoch 91/100
# 1/1 [==============================] - 0s 230ms/step - root_mean_squared_error: 0.4282 - factorized_top_k/top_1_categorical_accuracy: 0.0732 - factorized_top_k/top_5_categorical_accuracy: 1.0000 - factorized_top_k/top_10_categorical_accuracy: 1.0000 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 651.5083 - regularization_loss: 0.0000e+00 - total_loss: 651.5083 - val_root_mean_squared_error: 0.8548 - val_factorized_top_k/top_1_categorical_accuracy: 0.0291 - val_factorized_top_k/top_5_categorical_accuracy: 0.0583 - val_factorized_top_k/top_10_categorical_accuracy: 0.0777 - val_factorized_top_k/top_50_categorical_accuracy: 0.1456 - val_factorized_top_k/top_100_categorical_accuracy: 0.2427 - val_loss: 3212.4065 - val_regularization_loss: 0.0000e+00 - val_total_loss: 3212.4065
# Epoch 92/100
# 1/1 [==============================] - 0s 187ms/step - root_mean_squared_error: 0.4185 - factorized_top_k/top_1_categorical_accuracy: 0.0476 - factorized_top_k/top_5_categorical_accuracy: 1.0000 - factorized_top_k/top_10_categorical_accuracy: 1.0000 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 651.0557 - regularization_loss: 0.0000e+00 - total_loss: 651.0557 - val_root_mean_squared_error: 0.9623 - val_factorized_top_k/top_1_categorical_accuracy: 0.0243 - val_factorized_top_k/top_5_categorical_accuracy: 0.0583 - val_factorized_top_k/top_10_categorical_accuracy: 0.0777 - val_factorized_top_k/top_50_categorical_accuracy: 0.1408 - val_factorized_top_k/top_100_categorical_accuracy: 0.2427 - val_loss: 3218.5544 - val_regularization_loss: 0.0000e+00 - val_total_loss: 3218.5544
# Epoch 93/100
# 1/1 [==============================] - 0s 178ms/step - root_mean_squared_error: 0.4229 - factorized_top_k/top_1_categorical_accuracy: 0.0732 - factorized_top_k/top_5_categorical_accuracy: 1.0000 - factorized_top_k/top_10_categorical_accuracy: 1.0000 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 650.5357 - regularization_loss: 0.0000e+00 - total_loss: 650.5357 - val_root_mean_squared_error: 0.8525 - val_factorized_top_k/top_1_categorical_accuracy: 0.0437 - val_factorized_top_k/top_5_categorical_accuracy: 0.0583 - val_factorized_top_k/top_10_categorical_accuracy: 0.0777 - val_factorized_top_k/top_50_categorical_accuracy: 0.1456 - val_factorized_top_k/top_100_categorical_accuracy: 0.2427 - val_loss: 3222.6287 - val_regularization_loss: 0.0000e+00 - val_total_loss: 3222.6287
# Epoch 94/100
# 1/1 [==============================] - 0s 194ms/step - root_mean_squared_error: 0.4134 - factorized_top_k/top_1_categorical_accuracy: 0.0476 - factorized_top_k/top_5_categorical_accuracy: 1.0000 - factorized_top_k/top_10_categorical_accuracy: 1.0000 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 650.1017 - regularization_loss: 0.0000e+00 - total_loss: 650.1017 - val_root_mean_squared_error: 0.9597 - val_factorized_top_k/top_1_categorical_accuracy: 0.0243 - val_factorized_top_k/top_5_categorical_accuracy: 0.0583 - val_factorized_top_k/top_10_categorical_accuracy: 0.0777 - val_factorized_top_k/top_50_categorical_accuracy: 0.1456 - val_factorized_top_k/top_100_categorical_accuracy: 0.2427 - val_loss: 3228.4221 - val_regularization_loss: 0.0000e+00 - val_total_loss: 3228.4221
# Epoch 95/100
# 1/1 [==============================] - 0s 200ms/step - root_mean_squared_error: 0.4172 - factorized_top_k/top_1_categorical_accuracy: 0.0646 - factorized_top_k/top_5_categorical_accuracy: 1.0000 - factorized_top_k/top_10_categorical_accuracy: 1.0000 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 649.6034 - regularization_loss: 0.0000e+00 - total_loss: 649.6034 - val_root_mean_squared_error: 0.8507 - val_factorized_top_k/top_1_categorical_accuracy: 0.0388 - val_factorized_top_k/top_5_categorical_accuracy: 0.0583 - val_factorized_top_k/top_10_categorical_accuracy: 0.0777 - val_factorized_top_k/top_50_categorical_accuracy: 0.1456 - val_factorized_top_k/top_100_categorical_accuracy: 0.2427 - val_loss: 3232.6438 - val_regularization_loss: 0.0000e+00 - val_total_loss: 3232.6438
# Epoch 96/100
# 1/1 [==============================] - 0s 187ms/step - root_mean_squared_error: 0.4078 - factorized_top_k/top_1_categorical_accuracy: 0.0476 - factorized_top_k/top_5_categorical_accuracy: 1.0000 - factorized_top_k/top_10_categorical_accuracy: 1.0000 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 649.1881 - regularization_loss: 0.0000e+00 - total_loss: 649.1881 - val_root_mean_squared_error: 0.9563 - val_factorized_top_k/top_1_categorical_accuracy: 0.0291 - val_factorized_top_k/top_5_categorical_accuracy: 0.0583 - val_factorized_top_k/top_10_categorical_accuracy: 0.0777 - val_factorized_top_k/top_50_categorical_accuracy: 0.1456 - val_factorized_top_k/top_100_categorical_accuracy: 0.2427 - val_loss: 3238.0874 - val_regularization_loss: 0.0000e+00 - val_total_loss: 3238.0874
# Epoch 97/100
# 1/1 [==============================] - 0s 191ms/step - root_mean_squared_error: 0.4113 - factorized_top_k/top_1_categorical_accuracy: 0.0573 - factorized_top_k/top_5_categorical_accuracy: 1.0000 - factorized_top_k/top_10_categorical_accuracy: 1.0000 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 648.7111 - regularization_loss: 0.0000e+00 - total_loss: 648.7111 - val_root_mean_squared_error: 0.8486 - val_factorized_top_k/top_1_categorical_accuracy: 0.0291 - val_factorized_top_k/top_5_categorical_accuracy: 0.0583 - val_factorized_top_k/top_10_categorical_accuracy: 0.0777 - val_factorized_top_k/top_50_categorical_accuracy: 0.1456 - val_factorized_top_k/top_100_categorical_accuracy: 0.2427 - val_loss: 3242.4509 - val_regularization_loss: 0.0000e+00 - val_total_loss: 3242.4509
# Epoch 98/100
# 1/1 [==============================] - 0s 179ms/step - root_mean_squared_error: 0.4025 - factorized_top_k/top_1_categorical_accuracy: 0.0451 - factorized_top_k/top_5_categorical_accuracy: 1.0000 - factorized_top_k/top_10_categorical_accuracy: 1.0000 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 648.3145 - regularization_loss: 0.0000e+00 - total_loss: 648.3145 - val_root_mean_squared_error: 0.9533 - val_factorized_top_k/top_1_categorical_accuracy: 0.0291 - val_factorized_top_k/top_5_categorical_accuracy: 0.0583 - val_factorized_top_k/top_10_categorical_accuracy: 0.0777 - val_factorized_top_k/top_50_categorical_accuracy: 0.1456 - val_factorized_top_k/top_100_categorical_accuracy: 0.2427 - val_loss: 3247.5645 - val_regularization_loss: 0.0000e+00 - val_total_loss: 3247.5645
# Epoch 99/100
# 1/1 [==============================] - 0s 186ms/step - root_mean_squared_error: 0.4061 - factorized_top_k/top_1_categorical_accuracy: 0.0537 - factorized_top_k/top_5_categorical_accuracy: 1.0000 - factorized_top_k/top_10_categorical_accuracy: 1.0000 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 647.8590 - regularization_loss: 0.0000e+00 - total_loss: 647.8590 - val_root_mean_squared_error: 0.8464 - val_factorized_top_k/top_1_categorical_accuracy: 0.0340 - val_factorized_top_k/top_5_categorical_accuracy: 0.0583 - val_factorized_top_k/top_10_categorical_accuracy: 0.0777 - val_factorized_top_k/top_50_categorical_accuracy: 0.1456 - val_factorized_top_k/top_100_categorical_accuracy: 0.2427 - val_loss: 3252.0469 - val_regularization_loss: 0.0000e+00 - val_total_loss: 3252.0469
# Epoch 100/100
# 1/1 [==============================] - 0s 197ms/step - root_mean_squared_error: 0.3975 - factorized_top_k/top_1_categorical_accuracy: 0.0439 - factorized_top_k/top_5_categorical_accuracy: 1.0000 - factorized_top_k/top_10_categorical_accuracy: 1.0000 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 647.4802 - regularization_loss: 0.0000e+00 - total_loss: 647.4802 - val_root_mean_squared_error: 0.9504 - val_factorized_top_k/top_1_categorical_accuracy: 0.0291 - val_factorized_top_k/top_5_categorical_accuracy: 0.0583 - val_factorized_top_k/top_10_categorical_accuracy: 0.0777 - val_factorized_top_k/top_50_categorical_accuracy: 0.1408 - val_factorized_top_k/top_100_categorical_accuracy: 0.2476 - val_loss: 3256.8633 - val_regularization_loss: 0.0000e+00 - val_total_loss: 3256.8633

# %%
accuracy = one_layer_history.history[
    "val_factorized_top_k/top_100_categorical_accuracy"
][-1]
print(f"Top-100 accuracy: {accuracy:.2f}.")
# Out:
# Top-100 accuracy: 0.25.

# %%
def predict_movie(inputs, top_n=3):
    # Create a model that takes in raw query features, and
    index = tfrs.layers.factorized_top_k.BruteForce(model.query_model)
    # recommends movies out of the entire movies dataset.
    index.index_from_dataset(
        talents.batch(128).map(
            lambda x: (
                x["talent_id"],
                model.candidate_model({"talent_id": x["talent_id"]}),
            )
        )
    )

    # Get recommendations.
    _, titles = index(
        {
            "user_id": np.array([inputs["user_id"]]),
            "user_gender": np.array([inputs["user_gender"]]),
            "user_age": np.array([inputs["user_age"]]),
            "user_location": np.array([inputs["user_location"]]),
            "user_tags": np.array([inputs["user_tags"]]),
            "user_preferences": np.array([inputs["user_preferences"]]),
            "rating": np.array([inputs["rating"]]),
            "review": np.array([inputs["review"]]),
        }
    )

    print("Top {} recommendations for user {}:\n".format(top_n, inputs["user_id"]))
    for i, title in enumerate(titles[0, :top_n].numpy()):
        print("{}. {}".format(i + 1, title.decode("utf-8")))
        
    return titles

# %%
titles = predict_movie(
    {
        "user_id": "935fae71-86a1-4632-b979-b01b35d3ba1d",
        "user_gender": 0,
        "user_age": 25,
        "user_location": "Bali, Denpasar",
        "user_tags": "Pendaki|Bersepeda|Memancing|Fotografi|Berjiwa petualang",
        "user_preferences": "Pendaki yang suka petualangan dan fotografi alam. Hobi bersepeda dan memancing di waktu luang. Ingin bertemu teman yang memiliki semangat petualang.",
        "rating": 0,
        "review": "",
    },
    5,
)
# Out:
# Top 5 recommendations for user 935fae71-86a1-4632-b979-b01b35d3ba1d:
#
# 1. fc0f6e4b-c397-40a4-a24c-d08b92aedc45
# 2. 674c14d8-ed13-471a-aabf-ceef4e5bc44b
# 3. f2427a83-eb72-47dd-aeaf-cf131b5cefa2
# 4. ac56a04d-aa98-4591-8e8c-2b188040c114
# 5. d7a31753-7f7a-4d3a-80ec-bca26e578735

# %%
talents_df.loc[talents_df["talent_id"].isin(titles[0].numpy().astype(np.str_)), :].head()
# Out:
#                               talent_id               talent_name  \
# 0  fc0f6e4b-c397-40a4-a24c-d08b92aedc45   Pribadi Anwar Wicaksono
# 1  674c14d8-ed13-471a-aabf-ceef4e5bc44b           Perdana Anshari
# 2  f2427a83-eb72-47dd-aeaf-cf131b5cefa2    Dwi Nur Septasya Nahda
# 3  ac56a04d-aa98-4591-8e8c-2b188040c114     Asmara Tamara Liranda
# 4  d7a31753-7f7a-4d3a-80ec-bca26e578735  Adisyafitri Oky Septasya
#
#   talent_gender talent_birth_date  talent_age  \
# 0             L         24/4/1992          31
# 1             L         10/3/2005          18
# 2             P         10/3/2002          21
# 3             P         31/3/1992          31
# 4             P         12/7/1990          33
#
#                    talent_location  \
# 0                  Banten, Cilegon
# 1        Kalimantan Utara, Tarakan
# 2      Sumatera Selatan, Pagaralam
# 3  Sumatera Barat, Lima Puluh Kota
# 4      Kalimantan Timur, Samarinda
#
#                                          talent_tags  \
# 0  Badminton|Berjiwa petualang|Kpopers|Hiking|Ola...
# 1            Desain|Inovatif|Optimis|Seniman|Kreatif
# 2  Petualangan|Bersepeda|Kutu buku|Traveling|Kuliner
# 3      Analitis|Coding|Inovatif|Teknologi|Programmer
# 4          Ambisius|Membaca|Cerdas|Pengajar|Visioner
#
#                                   talent_description
# 0  Saya sangat menyukai Kpop, girlband favorit sa...
# 1  Saya adalah seorang seniman visual yang mencin...
# 2  Pecinta kuliner dan petualangan! Saya suka men...
# 3  Seorang pengembang perangkat lunak yang bersem...
# 4  Pengajar bahasa Inggris yang juga pencinta lit...

# %%
def predict_rating(inputs):
    trained_movie_embeddings, trained_user_embeddings, predicted_rating = model(
        {
            "user_id": np.array([inputs["user_id"]]),
            "user_gender": np.array([inputs["user_gender"]]),
            "user_age": np.array([inputs["user_age"]]),
            "user_location": np.array([inputs["user_location"]]),
            "user_tags": np.array([inputs["user_tags"]]),
            "user_preferences": np.array([inputs["user_preferences"]]),
            "rating": np.array([inputs["rating"]]),
            "review": np.array([inputs["review"]]),
            "talent_id": np.array([inputs["talent_id"]]),
        }
    )
    print("Predicted rating for {}: {}".format(inputs['talent_id'], predicted_rating.numpy()[0][0]))

# %%
predict_rating(ratings_df.loc[5])
# Out:
# Predicted rating for ebeec989-30a1-49fb-a40b-02a4bfbb6633: 3.365267038345337

# %%
ratings_df.loc[5:5, :]
# Out:
#                                 user_id                             talent_id  \
# 5  6a58a9cc-b016-4ff3-83d4-c41e735bf4df  ebeec989-30a1-49fb-a40b-02a4bfbb6633
#
#    rating                                             review  \
# 5       4  Layak dicoba. Kemampuan bermain badminton dan ...
#
#                talent_name  talent_gender talent_birth_date  talent_age  \
# 5  Allysa Finesh Anggraeni              1         16/5/1981          42
#
#          talent_location                                     talent_tags  \
# 5  Sumatera Utara, Medan  Seni|Kreatif|Fotografi|Ramah|Berjiwa petualang
#
#                                   talent_description       user_name  \
# 5  Pecinta seni yang memiliki ketertarikan pada a...  Kevin Setiawan
#
#    user_gender user_birth_date  user_age           user_location  \
# 5            0       9/13/2000        23  Sumatera Utara, Binjai
#
#                                           user_tags  \
# 5  Konsultan|Dokter|Sepak bola|Pet lovers|Memancing
#
#                                     user_preferences
# 5  Biasa diajak seneng bareng, maen game bareng, ...
